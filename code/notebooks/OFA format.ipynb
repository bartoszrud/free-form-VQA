# %%
import json
import pandas as pd
from PIL import Image
from io import BytesIO
import base64
import pickle
import warnings

# %%
warnings.filterwarnings(action='ignore')

# %% [markdown]
# The information of question-id, image-id, question, answer (with confidence), predicted object labels (taken from VinVL, slightly brings around +0.1 accuracy improvement), image base64 string are separated by tabs.

# %%
with open("../questions_validation.json", "r") as f_q:
    questions_val = json.load(f_q)

    
with open("../annotations_validation.json", "r") as f_a:
    annotations_val = json.load(f_a)
    
with open("../questions_training.json", "r") as f_q:
    questions_train = json.load(f_q)

    
with open("../annotations_training.json", "r") as f_a:
    annotations_train = json.load(f_a)

train_imgs_path = "/home/bartek/ETH/CS4NLP/project/train2014"
val_imgs_path = "/home/bartek/ETH/CS4NLP/project/val2014"
# test_imgs_path = "/home/bartek/ETH/CS4NLP/project/train2015"

# %%
ans2label = {}

answers_all = []

for annotation in annotations_val["annotations"]:
    for answer in annotation["answers"]:
        answers_all.append(answer)
#         print(answer)

for annotation in annotations_train["annotations"]:
    for answer in annotation["answers"]:
        answers_all.append(answer)
#         print(answer)

print(len(answers_all))

answers_all = set(answers_all)
answers_all = [answer.strip().rstrip(".").replace("\t", " ") for answer in answers_all]

print(len(answers_all))


for i, answer in enumerate(list(answers_all)):
    ans2label[answer] = i
# Out:
# 30841
# 30598

# %%
ans2label
# Out:
# {'A toothbrush with toothpaste next to a tube on a counter': 0,
#  'A cow statue outside of a shopping store': 1,
#  'A man is getting ready to fly a kite in a park filled with people': 2,
#  'a close up of food on a chopping board with broccoli': 3,
#  'A man in colorful dress and hat is tying ribbon on neck of a cow': 4,
#  'A young woman is catching a Frisbee with both hands': 5,
#  'A man riding a skateboard across a lunch area': 6,
#  'A sheepherder riding a brown horse with several horses trailing': 7,
#  'Leaking fire hydrant with growing grass and a puddle': 8,
#  'This young man is enjoying a hot dog with his dad': 9,
#  'Two laptop computers sit next to each other on a table': 10,
#  'A black cat is staring directly into the camera': 11,
#  'A child watches an airplane coming in from a boat': 12,
#  'A boy in black shirt standing on a baseball field': 13,
#  'a collage of photos with a lot of doughnuts': 14,
#  'Two gentleman are playing on the Wii': 15,
#  'a couple of people sitting on a couch plays with a wii remote': 16,
#  'This skier has just jumped from a ski slope': 17,
#  'There is graffiti portraying clothes hanging on a line': 18,
#  'The surfer is riding the wave on his surf board': 19,
#  'A person skiing down a snow covered mountain': 20,
#  'A fire place in a living room filled with furniture': 21,
#  'A herd of cattle eating hay inside of a barn near windows': 22,
#  'A light rail train has stopped at a station in the city': 23,
#  'A snow covered tree with stop sign by the street': 24,
#  'A man is walking a dog on a leash': 25,
#  'A dog jumps in front of a television in a living room': 26,
#  'a person standing on a street side walk wearing a suit and tie': 27,
#  'a traffic light, one way sign and crosswalk signal': 28,
#  'A cat with a look of annoyance standing on a toilet lid': 29,
#  'A large chocolate cake with a frosting man on top of it': 30,
#  'A girl with a blue shirt sits next to a suitcase': 31,
#  'Women with very small swimsuits pose and talk on the phone': 32,
#  'A carnival occurred on a beautifully sunny day': 33,
#  'An old fashioned kitchen with a green laminate counter top': 34,
#  'A couple of buses being driven down a road': 35,
#  'A black and gold clock sits against an old building': 36,
#  'I do not know what this image is': 37,
#  'The horse and puppy are separated by the mesh fence': 38,
#  'A group of elephants that are standing in the dirt': 39,
#  'A man sits proudly on a house outside': 40,
#  'A kitchen with wood cabinets and black and chrome appliances': 41,
#  'A man is walking in a park with a frisbee': 42,
#  'Drink and book sitting near a silver laptop on a table': 43,
#  'A woman walking her cattle down the road': 44,
#  'a horse and buggy that is going down a road': 45,
#  'The neck up of a giraffe standing next to rocks': 46,
#  'A two-person vanity is below a mirror in the bathroom': 47,
#  'A street sign "PeePee Falls St." sits on top of a stop sign': 48,
#  'Two giraffe standing next to each other on a dirt road': 49,
#  'A man in a reflective vest walks toward a parked airplane': 50,
#  'Two horned animals can be seen just past the fence': 51,
#  'A brown and white cat is sitting on a couch': 52,
#  'A skier wearing a red, white and blue ski suit skis down a mountain': 53,
#  'A black cat walking a ledge in a dark room': 54,
#  'A view of shower curtain, toilet and sink': 55,
#  'A dog lays on a blanket in the living room while it is all sunny': 56,
#  'A skateboarder jumps in the air to perform a stunt': 57,
#  'Various sink cabinets lined up in a warehouse': 58,
#  'A person standing with a backpack and a pair of skis on top of a slope': 59,
#  'a cat walking on a wooden floor': 60,
#  'A white and red airplane with the word KingFisher on the side': 61,
#  'a vase with pink roses sitting on a glass table': 62,
#  'four men playing  with a white frisbee at a park': 63,
#  'A simple kitchen with several cabinets and a fridge': 64,
#  'A baseball pitcher on the mound getting ready to throw the next pitch': 65,
#  'A man holding a white hair dryer in front of him': 66,
#  'There is a stop sign at a train crossing': 67,
#  'A man catching a neon frisbee while jumping into the air': 68,
#  'a man on a court that has a racket in hand': 69,
#  'A bride and groom pose for pictures in a garden': 70,
#  'Men are standing near a yellow tractor trailer': 71,
#  'A stuffed animal is standing in front of a window': 72,
#  'A laughing woman with an apple ornament dangling closely to her cheek': 73,
#  'a man is taking a bit out of a pizza': 74,
#  'Woman with her dog, and a fancy cake': 75,
#  'Older woman wearing sunglasses holding up green umbrella to keep sun away': 76,
#  'there is a jet that can be seen flying in the air': 77,
#  'An elephant putting its trunk in another elephants ear': 78,
#  'A small sheep stands next to a bigger sheep who is the parent': 79,
#  'Getting ready to fly an American flag kite': 80,
#  'four pictures with an elephant two lions two giraffes and two people': 81,
#  'a very nice microwave with its warning labels': 82,
#  'An elephant walking down a road near a forest': 83,
#  'People on a beach at dusk flying kites in the sky': 84,
#  'An orange cat sitting at corner of desk next to a keyboard': 85,
#  'A device that says "danger" in a briefcase': 86,
#  'A long train traveling across a street near a forest': 87,
#  'A man standing over a stove top oven in a kitchen': 88,
#  'A cat is playing with a toy underneath a stool': 89,
#  'Three people in black shirts playing with a white frisbee': 90,
#  'A plate of food that is on top of a table': 91,
#  'Man sitting at a table with a large pizza in a box in front of him': 92,
#  'Walkway near tower with clock and ornate sculpting': 93,
#  'This is a colorful bus stopped on a gloomy day': 94,
#  'A person and a backpack sitting on a bamboo bench': 95,
#  'A skateboarding getting major air off a ledge': 96,
#  'A motorcycle that is sitting in the sand': 97,
#  'A person dressed in a costume is having a good time': 98,
#  'A little boy that is standing in front of a refrigerator': 99,
#  'The eight lane street is packed with cars in traffic': 100,
#  'A bathroom with a bathtub, sink, toilet, a chair and some shelves and cleansers': 101,
#  'a boy jumping in the air with a skateboard above a skateboard park obstacle course': 102,
#  'A man riding skis down the side of snow covered slope': 103,
#  'A woman in a red shirt talking on cellphone at a counter': 104,
#  'Two adult sheep surrounding a lam near a gate': 105,
#  'A room with speakers, a monitor, headphones, blinds and a bed in it': 106,
#  "A black lab waits at a picnic table for it's master": 107,
#  'A street scene with a close of of a stop light': 108,
#  'Blurry photograph of a cat jumping up from a chair': 109,
#  'A man and a woman eating lunch at a restaurant': 110,
#  'A person holding a remote as it rests on a blanket': 111,
#  'A group of people sitting around a large wooden desk': 112,
#  'A man performing a skateboard trick down some stairs': 113,
#  'A parrot type bird holding onto the bars of its cage next to a mirror': 114,
#  'Some nicely dressed men standing near some microphones': 115,
#  'Two people playing tennis in a neighborhood park': 116,
#  'A small dog riding in a soft dog carrier': 117,
#  'an image of a bird in the water': 118,
#  'A dog and small child riding a bicycle': 119,
#  'A dirty plate on a counter with notes on it to someone': 120,
#  'The stop sign is spray painted over with words': 121,
#  'A man on a red bike about to cross a busy street': 122,
#  'A little boy rolls a Frisbee while a man in a sombrero watches': 123,
#  'a neatly arranged bathroom with shower, tub, toilet, and sink': 124,
#  'A pair of glasses with milk in them next to a blender': 125,
#  'Two tennis players are shaking hands over the net': 126,
#  'A piece of lasagna on a plate with a fork': 127,
#  'Four people are sitting on a bench overlooking the water': 128,
#  'Variety of vegetables being cut up and wrapped in foil': 129,
#  'A large white bowl filled with bananas and tangerines': 130,
#  'cows standing in their stalls in a bar feed on dried grass left for them to eat': 131,
#  'Black and white photo of woman surfing atop the ocean waves': 132,
#  'A small white bowl of salad and a drink': 133,
#  'a person in a shop with an open umbrella': 134,
#  'People gathering around a parked bus, some holding food': 135,
#  'a close up of a cat laying on a pair of shoes': 136,
#  'An old truck and memorabilia are featured in an exhibit': 137,
#  'An old open refrigerator in a dilapidated room': 138,
#  'three people performing stunts on scooters on a ramp': 139,
#  'A group of elephants standing around a wooden post': 140,
#  'a couple of meen are standing near a boat': 141,
#  'two people riding on horses in the middle of a lot': 142,
#  'A PERSON IS WALKING UNDER AN UMBRELLA': 143,
#  'Eleven carrots that were cleaned on a cutting board': 144,
#  'A large body of water below a tall cloud covered mountain': 145,
#  'A group of men on a field with baseball bats': 146,
#  'We are looking at a tennis player ready to return the ball': 147,
#  'Double decker city bus stopped and taking on passengers': 148,
#  'Small boat filled with fruit on a river filled with boats': 149,
#  'An array of pumpkins with faces painted on them': 150,
#  'Two zebras grazing in grass near one another': 151,
#  'A herd of cattle standing on  a lush green field': 152,
#  'Freshly fallen snow covers a bench and shrubbery': 153,
#  'An animal that is looking at the camera': 154,
#  'The reflection of a dog in the side view mirror of a car': 155,
#  'A woman smiles while standing near a sheep': 156,
#  "A zebra putting it's head on another zebra in their natural habitat": 157,
#  'A baseball batter watches a pitch go by': 158,
#  'A yellow truck sits parked in a parking lot': 159,
#  'A giraffe sitting in front of a wall of concrete and rope': 160,
#  'Pink flowers sitting in a blue and white vase with a pink background': 161,
#  'A woman has her cell phone up to her ear': 162,
#  'Two elephants touching their trunks in the outdoors by a lake': 163,
#  'A large swimming pool is next to a large harbor': 164,
#  'Two men at the bottom of a snowy mountain about to ski': 165,
#  'A woman is holding a purple, old-fashioned parasol': 166,
#  'A bunch of kids in a class room with laptops': 167,
#  'A Zebra is walking alone in the green gas': 168,
#  'A herd of elephants cross a shallow river': 169,
#  'six different pictures of the same tv screen': 170,
#  'a small vase with orange flowers and blue stems': 171,
#  'A white man drinking a drink and talking on his cell phone in a field': 172,
#  'A group of people on a beach with surfboards and kites': 173,
#  'THERE ARE FOUR DIFFERENT BOW TIE STYLES ON THE DISPLAY': 174,
#  'A person putting a tray of food into an oven': 175,
#  'A car is stopped at the intersection due to a red light': 176,
#  'a stop sign an one way sign and a street sign': 177,
#  'A man in public about to use his skateboard': 178,
#  'A cow lays on the grass inside a fence': 179,
#  'Grey commuter train at platform of covered station': 180,
#  'A man wearing glasses dressed in all black on a sidewalk': 181,
#  'The man is surfing on the river by the boats': 182,
#  'A man with no shirt is serving the ball in a tennis game': 183,
#  'A close shot of several different vegetables on a plate': 184,
#  'A dog sitting in front of celebratory doggy treats and cakes': 185,
#  'A long haired dog walking through the grass in the back yard': 186,
#  'A group of white sheep eating from blue bowls': 187,
#  'Bathroom with pictures and fixtures with wood cabinet and windows': 188,
#  'A traffic light with a picture of a coffee cup underneath it': 189,
#  'An old clock with a table and a chair on either side of it': 190,
#  'a car with a bike strapped on the trunk': 191,
#  'A group of people wearing orange are standing next to a VW bus': 192,
#  'An elephant is alone in a field of grass': 193,
#  'Herd of elephants walking following each other along a path': 194,
#  'two dessert type cakes on a counter in a home': 195,
#  'A couple of flowers inside a clear vase': 196,
#  'a young child cries as he sits on a bed': 197,
#  'A bathroom with the sink and its cabinet knocked out': 198,
#  'a skier is wearing a purple jacket and skiing and a chair lift': 199,
#  'there is a small baby laying in bed with a laptop': 200,
#  'A pink plate topped with two sausages on a bun': 201,
#  'a man that is surfing on a blue surf board': 202,
#  'A bowl and a jar of applesauce sits next to two apples on a white doily and striped red tablecloth': 203,
#  'A man in a suit with his arms crossed': 204,
#  'The lady in the picture is holding a little girl and fixing her hair': 205,
#  'Three giraffes standing in an enclosed area of dirt': 206,
#  'A boy playing a video game on his tv': 207,
#  'A baby elephant walks in its enclosure near an adult': 208,
#  'A boy jumping high in the sky on his skate board': 209,
#  'A person holding a Nintendo Wii Remote Controller': 210,
#  'A fuzzy brown dog is happy for a car ride': 211,
#  'A small pug dog standing over an aluminum can': 212,
#  'A bench sitting on the ground near trees and grass': 213,
#  'The tall tower of the building has a clock displayed': 214,
#  'A machine with lots of knick knacks on it': 215,
#  'A pitcher, a batter, and an umpire on a field': 216,
#  'a large airplane that is flying through the sky': 217,
#  'A patch of grass with lots of bikes parked on it': 218,
#  'A hot dog serves with fries and dip on the side': 219,
#  'A large truck driving down a road next to a car': 220,
#  'A BIRD ON A BRANCH RUFFLING ITS FEATHERS': 221,
#  'The green, glass vase is near window curtains': 222,
#  'a wooden bench in a park with flowers': 223,
#  'a couple of buses that are parked next to each other': 224,
#  'A traffic light sitting in a room next to a young man': 225,
#  'A large bottle of wine sitting on top of a table': 226,
#  'a small silver vase with some orange flowers in it': 227,
#  'Man driving a fire truck with two women as passengers': 228,
#  'a little league player at bat in front of the catcher playing in a field': 229,
#  'The remodel of a restroom, with a toilet in it': 230,
#  'A large tall metal clock on a road': 231,
#  'An elephant in the water inside its exhibit': 232,
#  'A man in a suit lean over his seat': 233,
#  'A street light and some trees on a street': 234,
#  'A man holding a microphone and notepad in one hand': 235,
#  'a man directing a plane on an air port run way': 236,
#  'A person on the water with a umbrella': 237,
#  'The boy smiles as he holds a video game remote in his hand': 238,
#  'Some people are in a parti flying a kite': 239,
#  'A happy boy is waiting outside with his suitcase': 240,
#  'A young child tries to balance on a skate board': 241,
#  'A picture of an elephant in a zoo enclosure': 242,
#  'This breakfast consists of a subway sandwich and a banana': 243,
#  'A white bird flying over water with a beach in the background': 244,
#  'A little dog is following a child on snow skis': 245,
#  'A man in grey shirt pumping fist and holding tennis racket': 246,
#  'A distance shot shows rolling snowy hills, partially shadowed, with ski prints reaching off into the distance, and to the foreground, a single skier': 247,
#  'A blue and white street sign next to building on lamppost': 248,
#  'A person in a dimly lit room reaches forward with a remote control': 249,
#  'a desk that has some computers on it': 250,
#  'a person wearing a suit and tie holding a guitar': 251,
#  'A young boy enjoys looking at a small frog on a Frisbee': 252,
#  'A cardboard box filled with a variety of fruits and vegetables': 253,
#  'A sink in a corner with two mirrors above it': 254,
#  'This is a skateboarder wearing jeans holding his skateboard at his right side': 255,
#  "A dog caching a neon frisbee in it's mouth": 256,
#  'A red beverage in a glass container sitting on a counter': 257,
#  'A large knife is sitting in front of a mug has a skull and crossbones': 258,
#  'A jockey riding in a cart pulled by a horse': 259,
#  'A blue metro train passes several buildings in the city': 260,
#  'a street light that is hanging by some buildings': 261,
#  'A homemade pizza is topped with cherry tomatoes and greens': 262,
#  'A brown bird is perched on a branch': 263,
#  'A porcelain toilet in a large home bathroom': 264,
#  'A boy is holding a skateboard to show the underside': 265,
#  'A grey and red train in an underground tunnel area': 266,
#  'A man stands with his hands up, while using an interactive video controller': 267,
#  'A giraffe bending down to eat or drink from behind some rocks': 268,
#  'A large living room is seen in this image': 269,
#  'A very tasty looking hot dog and some cooked potatoes': 270,
#  'Arrangement of clay roses in a vase on a cluttered table': 271,
#  'A woman holding a tennis ball and a racket on a court': 272,
#  'A red tooth brush sitting next to a tube of toothpaste': 273,
#  'Several trains parked together in a train yard': 274,
#  'The woman is kneeling down near another player during a game of Frisbee': 275,
#  'Large white bird flying above the water on a beach': 276,
#  'this is a bus parked in a garage with others': 277,
#  'A sleek train is in an overhead enclosure on tracks': 278,
#  'A giraffe bends over to nibble grass in a rock and lawn area at the zoo': 279,
#  'A house cat drinking water from a sink spigot': 280,
#  'A person with a tie and a cigarette in his mouth': 281,
#  'A donut maker handing a bag to a lady': 282,
#  'A wooden bench sitting in the woods off a path': 283,
#  'An airplane on the tarmac with an stair ramp': 284,
#  'Two cows, not fenced in, standing by the roadside': 285,
#  'Two young boys using their laptop computers at a wooden table': 286,
#  'A baseball player in white swinging at a baseball': 287,
#  'Two zebra backs are shown in this close-up picture': 288,
#  'a group of people on a tennis court': 289,
#  'a twin bed that is made up with blue, white, and green linens, in front of a dark window': 290,
#  'A family poses together on a beach where there are kites in the sky': 291,
#  'A grey and white striped cat sitting on a chair cushion on a wooden chair': 292,
#  'A selection of small desserts artfully displayed on a large, white plate': 293,
#  'A man takes a picture of a reflection in a mirror of white semi truck': 294,
#  'A young woman smiles in front of a sheep': 295,
#  'The giraffe has stuck his head through the fence': 296,
#  'A groups of skiers and snowboarders standing in the snow': 297,
#  'A cell phone lying on a picture of a young man holding a similar cell phone': 298,
#  'A man on a grassy field throwing a frisbee': 299,
#  'A man surfing in very rough waters wearing a black wet suit': 300,
#  'The empty bench is sitting in the nighttime street': 301,
#  "A long train of model animals on display to show how Noah's arc was filled": 302,
#  'This photograph depicts an incision during surgery along with some tools': 303,
#  'There is a keyboard, mouse, and remote, on a conference table': 304,
#  'A man sitting on a motorcycle in front of a garage': 305,
#  'Black and white photograph of a man flying a kite': 306,
#  'Group of people sitting in front of a television playing with a Wii': 307,
#  'A woman is attempting to reach for something, while holding a tennis racket': 308,
#  'Several boxcars with graffiti on them crossing a road': 309,
#  'Plane on tarmac being checked by worker on side': 310,
#  'A man riding a horse drawn wagon along side of a field': 311,
#  'A seafood appetizer served at an oriental restaurant': 312,
#  'A very cute black and white cat by a window': 313,
#  'A traffic light that is near a brick building': 314,
#  'a person is pushing a cart around some cops': 315,
#  'A man in a hat is walking a horse on the beach': 316,
#  'A teddy bear setup, standing on a table in a store': 317,
#  "A set of traffic lights showing green next to a sign that says 'no turn on red'": 318,
#  'A river with an elephant and several men standing around it': 319,
#  'A person skateboarding on a metal rail in a park': 320,
#  'A young man in a kitchen staring at a bottle of liquid': 321,
#  'A fat, minty green vase sitting on a table': 322,
#  'A boy biting into a piece of broccoli': 323,
#  'a couple playing doubles tennis together on a court': 324,
#  'A person is preparing to eat a large pizza': 325,
#  'A bowl that has apples and bananas in it': 326,
#  'A group of cars traveling down a street under traffic lights': 327,
#  'The three airplanes are parked together on the runway at the airport': 328,
#  'A whit toilet sitting in a bathroom next to a sink': 329,
#  'A herd of wild horses grazing on a lush green hillside': 330,
#  'I am unable to see the image above': 331,
#  'A young girl has her hands up to her mouth in the kitchen': 332,
#  'A herd of cows standing in a grassy field': 333,
#  'a vase has a bundle of flowers in it': 334,
#  'A person sleeping in a bed with a large black dog': 335,
#  "a blond dog with it's tongue hanging out": 336,
#  'A group of men riding motorcycles in street with American flags': 337,
#  'A man that is reading a newspaper is sitting on a step': 338,
#  'A man at a restaurant holding up a bowl of pickles': 339,
#  'A man in all black surfboarding catching a wave': 340,
#  'A yellow motorcycle parked on the side of the street': 341,
#  'a snow skier in a blue jacket is holding their arms up': 342,
#  'some people sitting at an outdoor table and talking to each other': 343,
#  'Two white teddy bears sitting next to each other on a bed covered in pillows': 344,
#  'A plane flying over a giant metal arch': 345,
#  'A living room area features a corner fireplace, a love seat, windows and lamps': 346,
#  'An elephant walks in the shallow water by the grass': 347,
#  'A brother and sister standing in the living room': 348,
#  'A woman sitting on a surfboard holding her dog': 349,
#  'Mountaineous view as seen from a jet airliner': 350,
#  'Some bags are coming around at baggage claim': 351,
#  'A young man is playing tennis and running for the ball': 352,
#  'A black calf stands in front of a wooden building decorated with images of Hindu deities': 353,
#  'Two people on a beach get ready to fly a kite': 354,
#  'An elephant sprays water as it stands in a shallow pool': 355,
#  'The young zebra has begun to form his adult stripes': 356,
#  'A yellow boat with people is in a canal': 357,
#  'A person performing a trick with his skateboard': 358,
#  'A chocolate cake sitting on top of a white plate': 359,
#  'A dog has came up from underneath a picnic table and rests his arms': 360,
#  'A man lays on the ground while a skateboard is in the air above the ground': 361,
#  'a girl riding a horse through an equestrian course': 362,
#  'A boy going up a ramp on his skateboard': 363,
#  'a man walking out of the water with his surfboard': 364,
#  'The flowers are on the table on display for everyone to see': 365,
#  'A cat sleeping a bowl on a table': 366,
#  'A large bus coming down a road with many buildings in the background': 367,
#  'Packaging for broccoli florets found at the grocery store': 368,
#  'A mother watches as her small toddler walks toward a yellow concrete pole': 369,
#  'A person holding a grey patterned neck tie': 370,
#  'A man sitting at a table with a plate full of food and drinks': 371,
#  'A woman on a cell phone outside near a wooded area': 372,
#  'A Coca-Cola bottle lying next to a keyboard with hand-shaped Coca-Cola key chains sitting on it,': 373,
#  'a baby boy with red shoes playing with magnets on a refrigerator': 374,
#  'a small pizza on a white plate with one slice taken out': 375,
#  'A  boy on a skateboard caught in mid jump': 376,
#  'A pizza cutter slicing up a food item on a cutting board': 377,
#  'A cat that is sitting on top of a speaker': 378,
#  'A man on a skateboard with a helmet and protective pads on, riding next to green cones on the street': 379,
#  'A child is standing at the counter of a donut shop': 380,
#  'A woman walking through an airport holding a piece of luggage': 381,
#  'A cat relaxes in its bed under the shade of an umbrella': 382,
#  'Air traffic on the tarmac and taking to the sky at an airport': 383,
#  'A guy standing in a small field with a big city behind him': 384,
#  'A man dressed in a burgundy vest wearing a glove holds an eagle': 385,
#  'An electric train stands on the train tracks': 386,
#  'This is two ladies playing tennis on a tennis court': 387,
#  'there is a vintage train coming up the tracks': 388,
#  'A man playing a game with a remote controller': 389,
#  'A close up of an orange cat laying on a laptop': 390,
#  'A woman is playing a video game in a room with a man': 391,
#  'A man, woman and child snowboard on a slope': 392,
#  'An alarm clock sits on top of a magazine': 393,
#  'Only an idiot would put mustard on a pair of sugar frosted donuts': 394,
#  'A bathroom has some decorative placed gray tile': 395,
#  'A man riding a bike next to a building housing a tarot shop': 396,
#  'a man in a suit and tie talking on a cell phone': 397,
#  'A herd of elephants walking across a grassy field': 398,
#  'A view of a plane from another plane window': 399,
#  'A stop sign that is listing to the side': 400,
#  'A big blue truck driving on a street': 401,
#  'A fruit stand that is filled with various fruits': 402,
#  'The cow is being looked at by the men in the building': 403,
#  'Graffiti painted onto the side of a train': 404,
#  'A man doing a wheelie on a motorcycle with a group of people standing and sitting in the audience area': 405,
#  'A bicycle chained to a rail near a flooded area': 406,
#  'a small cooler is on a wood table': 407,
#  'a number of pigeons near some benches in the background': 408,
#  "A picture of a Men's restroom with an urinal, trashcan, and toilet": 409,
#  'A red toaster oven sitting on the counter': 410,
#  'A person leaning against a skateboard standing upright': 411,
#  'A dog rests on a pillow on the ledge of a window': 412,
#  'A pizza on a place matt next to a wood spoon': 413,
#  'sink area of a kitchen with coral colored shelving': 414,
#  'SKIER COMING DOWN THE SLOPES JUST OUTSIDE THE CABIN': 415,
#  'An artistic view point of a business man staring off in the distance': 416,
#  'A white bowl filled with meat, veggies and broccoli': 417,
#  'A pair of skis in the open water': 418,
#  'A passenger bus is pulled up to a bus stop': 419,
#  'A bowl full of broccoli being shocked with ice': 420,
#  'A red antique truck among other antique trucks': 421,
#  'A room with a loft bed and a lot of computer equipment': 422,
#  'A group of sheep in a big field': 423,
#  'Cars drive through green traffic lights in a snowy area': 424,
#  'A man sitting at an office desk eating a burrito': 425,
#  'a stop sign stands at an intersection on a tree-lined street': 426,
#  'A bunch of cut meat sitting on a cutting board': 427,
#  'a person surfing under a wave in the ocean': 428,
#  'a kitchen with a pot rack on the wall': 429,
#  'An airplane on display behind a fence with a dusting of snow on the ground': 430,
#  'Fresh baked cookies layed out on parchment paper': 431,
#  'A street scene with a person riding a bicycle': 432,
#  'A man riding a snowboard on snow covered ground': 433,
#  'A woman sitting on some steps with a dog by a beach': 434,
#  'A person walking by looks at a trolley with graffiti on it': 435,
#  'A small white dog leaning up against a fence and horse leaning up against the fence on the other side,': 436,
#  'The person is holding the video game controller': 437,
#  'A blue and black motorcycle has a leather seat': 438,
#  'A group of desktop computers sitting on top of a desk': 439,
#  'Two men play Wii together while a baby watches': 440,
#  'A man riding a skateboard down a flight of steps': 441,
#  'two children standing with two adults in the background': 442,
#  'Three doughnuts on paper in a display basket': 443,
#  'A group of tables decorated for a large party': 444,
#  'Two men discussing and working with electronic equipment': 445,
#  'A black and white photo of two zebra': 446,
#  'Motorcycles and other vehicles parked in a parking lot': 447,
#  'Two giraffes standing next to each other on grass': 448,
#  'Three young girls holding ribbons in the snow': 449,
#  'People standing on the backs of elephants that are standing in the river': 450,
#  'A herd of elephants walking along side of  a train': 451,
#  'A stop sign in a residential area with a large cream colored house in the background': 452,
#  'A man is holding a wrapper with a hotdog': 453,
#  'A herd of zebra in a grassy are with bushes in the background': 454,
#  'a man standing by a selection of blue and white vases': 455,
#  'A girl and boy playing on a fire hydrant': 456,
#  'A dog wearing an elf hat sits in the snow': 457,
#  'a boy sitting while eating some cake on a plate': 458,
#  'Two men enjoying a meal outside, next to a lake': 459,
#  'A kitchen with an oven, stove, and refrigerator in a highlighted type picture': 460,
#  'two bears are brawling in a shallow lake': 461,
#  'a lady in a school smiling holding a desert she baked for some one': 462,
#  'Two people beside one another while one holds a baseball glove and the other wears a baseball hat': 463,
#  'A young man navigates his skateboard down a ramp': 464,
#  'an animal sits inside of a bag on a chair': 465,
#  'The brown bear is wearing a pretty red hat': 466,
#  'A man on a skateboard skating in a skate park': 467,
#  'Temple Bar with museum signposts in the heart of Dublin': 468,
#  'A cat is shown trying to bite the cap of a bottle': 469,
#  'a group of animals laying around in the grass': 470,
#  'Two children smiling on top of luggage in parking lot': 471,
#  'An outdoor train station with three visible trains and many people': 472,
#  'A giraffe walking through the grass towards a wall': 473,
#  'The street is lined up and down with motorcycles': 474,
#  'A picture of the inside of a house with a wheel barrel visible': 475,
#  'A green house filled with lots of green stuff': 476,
#  'Ingredients for making a pie in front of an iPad on a kitchen counter': 477,
#  'Two baby elephants take a drink from a trainer in an enclosure': 478,
#  'a couple of pieces of fruit in a white bowl': 479,
#  'Two cats are on the floor, one in a pet bed': 480,
#  'a big pile of bananas that are on a table': 481,
#  'The bus has an unusually odd shaped nose': 482,
#  'A large black dog sitting in the back seat of a car': 483,
#  'A baseball player is starting to run to first base': 484,
#  'Two cows walk down a street as people pass by': 485,
#  'a mom and her daughter and her daughter does not feel good as they lay in bed': 486,
#  'A dirt bike rider is racing on a dirt course': 487,
#  'A woman talks on her phone while riding her bicycle': 488,
#  'An airplane flies close to the water near an island': 489,
#  'There is a large slice of barbecue chicken pizza in a cardboard box': 490,
#  'The people are feeding the giraffes at the zoo': 491,
#  'A couple with their computers in bed with "Weekend" on a magazine page': 492,
#  'A big boat anchored next to a big dock': 493,
#  'A polar bear plunges into the cold water': 494,
#  'a sheep laying down and napping in front of the barn': 495,
#  'A group of people standing in a kitchen': 496,
#  'A horse leans over the fence to talk to a dog': 497,
#  'A group of people sit at a table with food': 498,
#  'A plate with a food made up of different things and a parsley garnish': 499,
#  'A black and white picture of some people by a clock': 500,
#  'a person riding a motorcycle in the reflection': 501,
#  'A man and woman sitting on a bench at a park': 502,
#  'In a sequence of 9 photos, a skateboarder jumps a park bench': 503,
#  'A building with a sign that reads "universal glass let us see your crack."': 504,
#  'A woman on a surfboard is riding a wave': 505,
#  'a bus full of people sitting in seats and a dog sitting on the floor': 506,
#  'a street sign next to a tree lined street': 507,
#  'a white cat covering itself with an umbrella': 508,
#  'A woman holds onto her hard-sided suitcase a hallway': 509,
#  'A man sitting on a bed in front of two laptop computers': 510,
#  'A boy playing with two Wii controls in his pajamas': 511,
#  'A sunlit room with wood floors and glass doors': 512,
#  'A man standing on a train stopped in the country': 513,
#  'A red fire hydrant and four little things close by': 514,
#  'A pizza on a wooden plank on top of a stove': 515,
#  'A zebra and a gazelle eating grass in a field': 516,
#  'Two people in bed working on their computers': 517,
#  'A man is looking over a railing out at the ocean': 518,
#  'A black and white photo of a small plane': 519,
#  'COLORFUL BRIGHT EYED CAT SURROUNDED BY ALL BLACK AND WHITE BOTTLES AND CANS': 520,
#  'Men are riding horses past other men working on a motorcycle': 521,
#  'A man holding a black umbrella herding cattle': 522,
#  'A bird stands on the sand by the water': 523,
#  'Street signs on a building in a foreign country': 524,
#  'Three stop lights that are hanging from a pole': 525,
#  'A couple of women sitting at a table with a plate of food': 526,
#  'there is a large building with a tower and a clock': 527,
#  'Bathroom sink next to soap and paper towel dispenser': 528,
#  'A man and a little girl pose with a surfboard in front of a shop': 529,
#  'a guy long boarding in the parking lot near a road': 530,
#  'A bathroom is decorated in red and neutrals with a bowl sink': 531,
#  'A blanket with various items that include a mouse, computer hard drive and a keyboard': 532,
#  'A counter top with a sink and a red vase': 533,
#  'A pink van parked on the side of a city street': 534,
#  'A plate of food with onions, broccoli and meat': 535,
#  'a fresh artisian pizza with sausage and cheese on a table': 536,
#  'Many people walking down a small city street by the water': 537,
#  'A group of tourists looks at a sign with Olympic information': 538,
#  'a close up of a person and a cow behind a fence': 539,
#  'a couple of people are holding rackets at a tennis game': 540,
#  'Couple of young girls matching pink outfits': 541,
#  'Some people are getting ready for a such event': 542,
#  'a red stop sign with a street sign attached': 543,
#  'A group of cops with dogs and horses standing next to a tall building': 544,
#  'Two people riding on the back of a large elephant': 545,
#  'People are in museum setting with a big statue': 546,
#  'Several people playing frisbee in a suburban park': 547,
#  'a dog that is eating some kind of cake on a table': 548,
#  'A skier bends down as he travels on the slope': 549,
#  'A man riding a skateboard off the side of a metal ramp': 550,
#  'This is a series of benches along a busy street': 551,
#  'Family of giraffes standing out in the open': 552,
#  'A green vase filled with purple flowers on a table': 553,
#  'A small herd of elephants with large white tusk': 554,
#  'Small white fluffy cat playing on a keyboard of a laptop computer': 555,
#  'Shoeless man sitting on the couch next to a window': 556,
#  'A series shot shows a person doing a flip on a ramp with a scooter': 557,
#  'Motion blur photograph of an oriental street at night': 558,
#  'some stuff is blended inside of a blender': 559,
#  'A group of zebras are walking through a field': 560,
#  'kid sticks out his tongue while the three of them pose for the picture with the cake': 561,
#  'A double decker bus and a truck driving next to each other': 562,
#  'a laptop sitting on a desk with some clear cases next to it': 563,
#  'a building with a pole and some street signs': 564,
#  'A woman standing on a  tennis court with a racquet': 565,
#  'A few people climbing on rocks, one holding an umbrella': 566,
#  'A young man stirring a pot of cooking food': 567,
#  'A man laying on the ground in front of a motorcycle': 568,
#  'A cat is sleeping in a cat bed under an umbrella': 569,
#  'A kitchen area with sink, dishwasher and refrigerator': 570,
#  'A commercial jet open and parked at the edge of the tarmack': 571,
#  'A train or trolley car is shown near a station': 572,
#  'A black and white photograph of a stuffed teddy bear wearing a shirt that reads "handle with care" and a small stuffed sheep': 573,
#  'A row of metal doors leading to an airport concourse': 574,
#  'A woman is poised, ready to strike a ball with her tennis racket': 575,
#  'A man holding a donut in a kitchen': 576,
#  'A square pizza sits on a pan next to a monkey plate': 577,
#  'A couple of men and one young man eating pizza': 578,
#  'A boy is ready to swing at a baseball pitch': 579,
#  'A white bird flying over the blue water': 580,
#  'The tennis player extends his arms upward while holding a racket': 581,
#  'Two sheep in a field with grass during the early evening': 582,
#  'A giraffe is peeking and smiling over a railing': 583,
#  'Two boys wearing different soccer uniforms are trying to kick a soccer ball': 584,
#  'A clock is seen in front of a tall tree': 585,
#  'Portion of a keyboard and an apple mouse on a wood table': 586,
#  'Two plants that are sitting next to each other': 587,
#  'two bicycles parked near a garden area in a park': 588,
#  'A park bench placed near an open field': 589,
#  'a table set up for a dinner for two': 590,
#  'Three policemen riding alongside each other on horseback': 591,
#  'A man on the beach holding a blue surf board': 592,
#  'A group of people riding skis across a snow covered ground': 593,
#  'a tabby cat hiding from two white ducks in a field': 594,
#  'A traffic light on a pole on a street': 595,
#  'A bus stopped in a bus stop as people cross the street': 596,
#  'A motorcycle is parked on a beach near a lighthouse': 597,
#  'A baseball game in progress and a man sliding into home base': 598,
#  'A bearded young man with his finger in his mouth': 599,
#  'Many old luggage suitcases are stacked against a brick wall': 600,
#  'A man smoking while looking over the interstate next to road signs': 601,
#  'A large cushioned chair with a laptop, pillow, remote, a tablet and a cell phone on it': 602,
#  'A man is holding a fork over a cake': 603,
#  "It's two kids to a computer in this classroom": 604,
#  'Utensils and containers line the sink in a kitchen': 605,
#  'a large group of cows standing in a green pasture': 606,
#  'there is a large bowl with vegetables  and dip in the middle': 607,
#  'black and white picture of a skillet and utensils for cooking': 608,
#  'The catcher and umpire are at home plate at a baseball game': 609,
#  'A bed is only half way made with cow designed sheets': 610,
#  'a close up of a cat sitting on a bench': 611,
#  'A shadowed bird wings its way across a reddish sky with a low sun that rests over a watery expanse': 612,
#  "A cat sitting on someone's lap staring at the person": 613,
#  'A gigantic blow up animal outside of a building with many glass windows': 614,
#  'A new bathroom installed in an attic space': 615,
#  'a blue and white fire hydrant sittting at the airport': 616,
#  'two people standing on top of a hill with skis': 617,
#  'A bench in a park with bare trees': 618,
#  'Three giraffes crossing the road to reach the field': 619,
#  'Two giraffes walking in a large grassy field': 620,
#  'A toilet with a red seat in a small bathroom with red tiles': 621,
#  'a couple of girls that are sitting on the ground': 622,
#  'A white castle cheese burger sitting on a plate with a fork': 623,
#  'A bunch of ripe bananas sitting on a cutting board next to Grape-nuts and yogurt': 624,
#  'A park landscape with a hammock by a tree': 625,
#  'Man in blue shorts and grey shirt swinging at a tennis ball': 626,
#  'Green train engine letting out black smoke from smoke stack': 627,
#  'A table set with food for Easter dinner': 628,
#  'Statue of a horse standing on a large red chair': 629,
#  'A person with a baseball bat and a hat': 630,
#  'A man is using a pole to move his boat through the water': 631,
#  'A funny storefront sign and motto on the building': 632,
#  'a truck sits in traffic next to other cars': 633,
#  'A desk with with one computer and two monitors': 634,
#  'Birds are eating bananas from an outdoor bird feeder': 635,
#  'A bright umbrella on a patio with stone steps leading to it': 636,
#  'A couple of cars that are in the dirt': 637,
#  'A man ordering hotdogs from a tent vendor': 638,
#  'A man is on a cement bench on a skateboard': 639,
#  'A colorful bus on the side of a road': 640,
#  'Man on surfboard riding frothy wave near beach': 641,
#  'a tennis player swinging a racket at a ball': 642,
#  'Traffic waits at the intersection as a man walks by on the crosswalk': 643,
#  'a sink a toilet a window and a towel rack': 644,
#  'A city street filled with traffic next to tall buildings': 645,
#  'A close-up of the miniature red reclining chair': 646,
#  'Vehicle traffic beside a colorful clock tower with a gold dome': 647,
#  'A dog wears a tie while on the steps': 648,
#  'Red fire hydrant with swamp and trees with grass': 649,
#  'This lady is walking with a man is talking on a cell phone': 650,
#  'A small airplane flying up over a island': 651,
#  'A dog is curled up under a blanket laying on its back': 652,
#  'A group of green traffic lights on a street filled with snow': 653,
#  'Two park benches with one man sitting in woods': 654,
#  'Two people sitting on a motorcycle sitting in traffic next to a bus': 655,
#  'A person surfing in the air, with a wind board': 656,
#  'A clean and neat room with chairs and a couch in front of a television': 657,
#  'A man walking a dog in grass in front of multiple busses': 658,
#  'The couch is in front of the television set': 659,
#  'a very big  fridge with nothing inside it': 660,
#  'A person near a large screen with others at a long table': 661,
#  'A man walking with a horse on the beach': 662,
#  'A group of men standing on a pier with a woman and a dog nearby': 663,
#  'There are several zebras moving in a savannah scene near a barren tree': 664,
#  'A very cute cow laying in a grassy field': 665,
#  'A black and white image of a plane flying': 666,
#  'A long bus pulling into a bus stop near buildings': 667,
#  'A bird sits on a branch covered in rope on a street': 668,
#  'I stumble into town, just like a sacred cow': 669,
#  'A man in a blue beach chair underneath an umbrella at the beach': 670,
#  'a close up of a duck in a body of water': 671,
#  'A four way stop sign on a pole': 672,
#  'This giraffe has two horns on the top of its head': 673,
#  'a lady kissing a man on the cheek': 674,
#  'Picture of a small aircraft on a runway': 675,
#  'Several road signs, including an El Rapido in a downtown area': 676,
#  'A large room with a ben and some chairs': 677,
#  'two large trucks are in a parking lot': 678,
#  'People are gathering at a table for a seminar': 679,
#  "An arrangement of items from a woman's purse including wallet, cell phone, MP3 player, gloves, hairbrush, eyeglasses case and day planner": 680,
#  'A young foal licks the head of an older horse': 681,
#  'Two adult sheep lay on the green grass': 682,
#  'A teddy bear with a blue coat on and a red hat': 683,
#  'Bunches of bananas stacked up on a table': 684,
#  'A group of tents is set up in very cloudy conditions': 685,
#  'Several stacks of white cups in a restaurant': 686,
#  'A view of street signs, electrical lines and the top of homes': 687,
#  'An open laptop computer on top of a desk': 688,
#  'An enormous black teddy bear in front of a teddy bear shop': 689,
#  'An empty bed with a wooden headboard in a bedroom': 690,
#  'A woman walking a dog through the woods': 691,
#  'A lot of people that are about to sky in the snow': 692,
#  'An elephant has his trunk in the sand': 693,
#  'Two men who are working in a kitchen': 694,
#  'There is a teddy bear wrapped in cellophane on the park bench': 695,
#  'A short table with cushions surrounding it in a log cabin': 696,
#  'there are many different foods on a white plate': 697,
#  'A woman standing in a kitchen near a counter': 698,
#  'A man on a skateboard that is on the sidewalk': 699,
#  'a close up of a pizza with different toppings': 700,
#  'A smiling woman and a man dressed in black': 701,
#  'A rusted business sign is attached to a building': 702,
#  'A large black bus with yellow numbers parked': 703,
#  'An old fashioned picture has a girl and a cow': 704,
#  'A photo of people and buildings and a large bus': 705,
#  'A sandwich on cornbread with several toppings on it': 706,
#  'There are some bicycles laying on their sides': 707,
#  'A man is looking through the handle of some scissors': 708,
#  'A couple of metal tables with a large umbrella over them': 709,
#  'A blurry view of a line of tennis courts, some with players': 710,
#  'Red potatoes is accompanied by a pie like entree': 711,
#  'An eagle sitting on the top of a green tree': 712,
#  'A baseball player is in position to bat': 713,
#  'A man who is making a baseball bat': 714,
#  'Brown horses are running on a green field': 715,
#  'A black dog laying on a pile of clothes': 716,
#  'The surfer has the right stance on his surfboard': 717,
#  'Three giraffe standing next to a fence under a lot of trees': 718,
#  'A large church like building with a clock on the steeple': 719,
#  'A woman in a hair net in a bakery holding a box': 720,
#  'A young girl puts an umbrella on a fire hydrant': 721,
#  'The human traffic at the top of a ski lift': 722,
#  'a dog wearing a lifejacket while surfing in the water': 723,
#  'A plane on the runway of an airport': 724,
#  'Soccer Players on a field with a few fans in the stands': 725,
#  'A metal casing in front of a refrigerator': 726,
#  'A kitchen has a stainless steel sink island': 727,
#  'A tall monument has a clock on the very top': 728,
#  'Black male and white female mannequins posed beneath spotlights': 729,
#  'A street sign sitting on top of another sign': 730,
#  'an image of a black cat sitting on a green bench': 731,
#  'A boat filled with produce covered by umbrellas': 732,
#  'A cat cleaning itself on the hood of an old car': 733,
#  'Two people standing on the grass playing soccer': 734,
#  'a living room with a couch near a bed room': 735,
#  'A group of people standing around with a kid and two sleds': 736,
#  'four donuts sitting on top of a counter next to a sink': 737,
#  'A toilet in a room with wooden walls': 738,
#  'a small baby is biting into some food': 739,
#  'A single basin bathroom sink with a granite vanity': 740,
#  'Little girl with a group of children watches a show': 741,
#  'Here is a picture of a purple and black striped socks with new black and white sneakers': 742,
#  'a large tower that has a big clock on it': 743,
#  'Two people are riding elephants in the streets': 744,
#  'Various fruits cut and displayed on a platter': 745,
#  'A person standing on a skatebord on some grass': 746,
#  'Cooked items with vegetables on plate for consumption': 747,
#  'Two adults and two children posing for the camera in their snow gear': 748,
#  'The man is cleaning with the dish detergent Palmolive': 749,
#  'A man in business attire is standing folding his arms': 750,
#  'A young boy wearing a jacket rides a green skateboard down the street': 751,
#  'A nearly empty plate containing broccoli and brown sauce': 752,
#  'A bathroom with dual sinks and the tub in a seperate room': 753,
#  'Three zebras are standing in an open area': 754,
#  'A man and two women sampling some wine': 755,
#  'A street sign sitting above a speed limit sign': 756,
#  'Uniformed baseball fielder waiting for play to resume': 757,
#  'A bathroom with a toilet, a tub and a mirror': 758,
#  'A man is riding a skateboard on the sidewalk': 759,
#  'some people and some black and white horses water and trees': 760,
#  'The man walks through a snow trail wearing skis': 761,
#  'A vintage photo of a pony express rider reaching into a mailbox at a farm, watched by a dog': 762,
#  'a close up of luggage bags on the ground': 763,
#  'A classroom scene with people sitting at a table and a man next to a presentation screen': 764,
#  'There is a close up picture of chocolate cake': 765,
#  'An old clock that is sitting on the mantle of a fireplace': 766,
#  'A group of kites flying over very poor homes': 767,
#  'A person doing tricks on a snowboard in the snow': 768,
#  'A giraffe gets some food from a wood box': 769,
#  'Several boats are docked on water near a lighthouse': 770,
#  'Two elephants in a grassy field with trees in the background': 771,
#  'this is a man riding a bike down the street': 772,
#  'A group of people sitting around each other in a park': 773,
#  'a large building, leafless trees and a fountain': 774,
#  'A person in boat on water with island in distance': 775,
#  'Half of a pepperoni pizza on a tray': 776,
#  'The light is shining through the window on the refrigerator': 777,
#  'A gigantic clock is displayed on the side of a building': 778,
#  'A woman that is laying down on a bench with a cellphone': 779,
#  'two policemen on horseback ride through a park': 780,
#  'A man riding a horse during a horse race': 781,
#  'A desert dish has powdered sugar on it': 782,
#  'An orange tabby cat curled up in a bowl': 783,
#  'A man riding up the side of a wooden ramp': 784,
#  'There are two people on a gravely area with benches on it that is encompassed in the background  by a green slope bordered by lush vegetation and a blue sky': 785,
#  'a cow in the waters and boat sailing': 786,
#  'A dog is chewing on a red coach': 787,
#  'Surfers catch waves in the ocean near a pier': 788,
#  'A man wearing a red neck tie and a jacket': 789,
#  'A man in a field grasps onto a large kite': 790,
#  'A large bear standing on a small cliff and two smaller bears climbing down the cliff': 791,
#  'a dining room table is set up at a fancy restaurant': 792,
#  'A group of people eating doughnuts on a string': 793,
#  'A poultry dish with broccoli on a blue plate': 794,
#  'A desk that has a drink in the middle of it': 795,
#  'A woman in a white dress and someone with a striped umbrella seated by a pond': 796,
#  'Three guys on the beach while one gets ready to ride a surf board': 797,
#  'A row of orange teddy bears with hearts are hanging on a net': 798,
#  'A large truck filled with produce driving down a street': 799,
#  'A blue bird sitting on a container with food in it': 800,
#  'A black white photo of a lady tennis player': 801,
#  'A man in a brown jacket stands near three goats in the grass': 802,
#  'A woman on a couch with a baby playing Wii': 803,
#  'A man serves a tennis ball on a court': 804,
#  'a clock attached to a wall with satutes': 805,
#  'Suitcases on top of a carrier onto of a vehicle': 806,
#  'A man holding a frisbee on a field next to a tent': 807,
#  'A man sitting near a guitar and a blue chair': 808,
#  'People are skiing in the snow near trees': 809,
#  'One bench next to a damaged and bent bench in the park': 810,
#  'A man in a Hawaiian t-shirt looking at an orange and red motorcycle with flames on it': 811,
#  'Female tennis player in a purple uniform ready to play': 812,
#  'A man and woman are standing together eating cake': 813,
#  'Four plates have been placed around a vase of flowers': 814,
#  'A view of a living, dining and kitchen area of an apartment': 815,
#  'A group of people riding paddle boats on top of blue water': 816,
#  'A horse on top of a big red chair': 817,
#  'Adults playing with frisbees in a verant park': 818,
#  'A large commercial airplane parked outside a window': 819,
#  'Wallpapered bedroom with purple comforter and vanity in the corner': 820,
#  'Three women cooking food outdoors using wood fires': 821,
#  'A zebra and oryx graze facing each other': 822,
#  "A man holds an elephant's tusk while it paints a picture": 823,
#  'A person on a motor bike on a street': 824,
#  'A man in China rides a bicycle and wears an umbrella': 825,
#  'A group of giraffes are walking in a desert': 826,
#  'a lot of cars on a city street with a sky background': 827,
#  'A blue and red train going down the tracks': 828,
#  'Four clocks hanging above a large open doorway': 829,
#  'a policeman wearing a yellow jacket is riding his yellow motorcycle': 830,
#  'Many different signs cover a post next to a bus stop': 831,
#  '2 giraffes walking on a open valley on a clear day': 832,
#  'A man with a baseball mitten plays baseball': 833,
#  'A tennis player wearing black shorts and a t-shirt holds a racket out': 834,
#  'a teddy bear with a bottle pacifier and a rattler': 835,
#  'A clean bathroom is seen in this image': 836,
#  'A pile of smoking hot coals sitting next to pots and pans': 837,
#  'A white toilet sitting next to a bath tub': 838,
#  'A gray cat is sitting in a blue suitcase': 839,
#  'Commuter bus on roadway with rows of building on hillside in background': 840,
#  'A setting of patio tables and chairs with umbrellas': 841,
#  'A pizza with different toppings sitting on a pan': 842,
#  'The beige dog has a blue blue collar': 843,
#  'a person surfing on very strong waves in the ocean': 844,
#  'A couple of young men surf and swim by the pier': 845,
#  'A young man is testing his strength, throwing his Frisbee': 846,
#  'A white ceramic vase shaped liked pistols with flowers in the barrel': 847,
#  'The young boy is talking on a cell phone': 848,
#  'A plate topped with veggies and chicken wings with two dipping sauce': 849,
#  'A group of men sitting next to each other': 850,
#  'a couple of bikes lean against a railing': 851,
#  'A bathroom has a toilet, shower, and counter in it': 852,
#  'a zoomed in image of various and multiple vegetables': 853,
#  'A woman and two men having a conversation': 854,
#  'a man in yellow is skiing in the snow': 855,
#  'A tennis player is bending his knees to the side to hit the ball': 856,
#  'Animated white female and black male in mirrored reflection': 857,
#  'People purchasing food from Stirchley Stores food cooperative': 858,
#  'A baseball player getting ready to swing the bat ': 859,
#  'A wine bottle that is standing next to wine glasses': 860,
#  'A Cardinal bird siting on a gray rock near a tree': 861,
#  'People are sitting on the sidewalk and relaxing by the river': 862,
#  'A batter lifts his left foot as he swings the bat': 863,
#  'a close up of three pastries shaped like pumkins': 864,
#  'A group of bicyclists stopping for a rest': 865,
#  'A man and woman standing over a box of donuts': 866,
#  'A parking lot line with parked cars in front of a building': 867,
#  'a building with a sign attached to it': 868,
#  'A clothes line with clothes hanging from it and cattle in the background': 869,
#  'The plane is flying up in the sky': 870,
#  'A small dog is sleeping in the rocking chair': 871,
#  'a lady is sitting on a suitcase with a dog next to her': 872,
#  'Two children standing at the sink brushing their teeth': 873,
#  'There are many signs on a busy downtown street': 874,
#  'A large living room with a large sofa and chair': 875,
#  'Two giraffes and an ostrich in front of an artificial rock wall in a zoo': 876,
#  'A tablet with attached keyboard, smartphone, and remote are ready on the couch': 877,
#  'A bride and groom cutting their wedding cake': 878,
#  'a zebra looking behind while standing on a dirt field next to shrubbery': 879,
#  'A mountain slope photo with a person on skis in the foreground': 880,
#  'Two dogs sitting on a mat in the back of an automobile': 881,
#  'a stop sign on a pole next to a tree': 27269,
#  'A laptop computer sitting on top of a dark wooden desk': 883,
#  'A red hammock set up in a wooded park': 884,
#  'Two people are touching a large gray elephant': 885,
#  'Two mirrors, two sinks, three lights, a window and a door': 886,
#  'Two large vases with paintings on the side of them': 887,
#  'A group of soldiers are holding and wheeling luggage': 888,
#  'A person on a surfboard being watched by people on a beach': 889,
#  'A pair of people hiking up a mountain with some skis on': 890,
#  'People with umbrellas over their head and another on the phone': 891,
#  'A man and a woman standing near a speedboat': 892,
#  'Baskets of apples are set on top of a wooden table': 893,
#  'a bunch of plants growing out of the dirt': 894,
#  'A turkey sandwich served with a pickle on the side': 895,
#  'Two water skiers flying in the air while a small crowd watches': 896,
#  'Two people wearing helmets on a yellow motorbike in front of a brown gate, beside a wooded area with trees': 897,
#  "A lion with something in its' mouth as it looks at something": 898,
#  'A baby stands near a toilet in the bathroom': 899,
#  'A group of friends sits in their living room while playing video games': 900,
#  'A cat lying near some pillows on a bed': 901,
#  'flower garden with large pink umbrellas behind guard rail': 902,
#  'A man is sitting at a Japanese restaurant eating a variety of sushi': 903,
#  'A man that is sitting next to a woman': 904,
#  'A wild animal walking across a grass covered field': 905,
#  'A sheep standing next to another sheep standing in a blue tub': 906,
#  'The little girl is playing a video game': 907,
#  'a couple of people are playing video games in a room': 908,
#  'A white bus parked in the middle of a parking lot': 909,
#  'A white and red bus is going down the street': 910,
#  'Open purple umbrellas resting on a pink fence': 911,
#  'A guy doing a skateboard flip in the middle of a park': 912,
#  'a man is striking a ball with a bat': 913,
#  'This man is eating a donut at an outdoor event': 914,
#  'A soldier on the flight deck of an aircraft carrier as a jet arrives': 915,
#  'Two skiers trekking through the snow on an overcast day': 916,
#  'A bunch of cakes are sitting on the counter': 917,
#  'An orange in a bowl near a puddle of water': 918,
#  'An artistic image of a stop sign in front of trees and a house': 919,
#  'There is a small toy penguin on top of a car': 920,
#  'Woman stands in front a maps covered wall holding a briefcase': 921,
#  'A young man with a surfboard at the ocean waters surfing': 922,
#  'Seven people are standing outside of a vending truck': 923,
#  'a person taking a photo in a mirror': 924,
#  'A man with a bow tie sits in a car with a hat on his head': 925,
#  'two little league players talking to each other in the outfield': 926,
#  'Several elephants crossing through a small river in the woods': 927,
#  'A large tower like structure that has a clock on it': 928,
#  'three giraffes are together in their pen and some trees': 929,
#  'a boy going down steps on a skate board': 930,
#  'A man sits silently in front of a microphone': 931,
#  'A man on a snow board high in the air': 932,
#  'someones desk with his wallet and charging cell phone': 933,
#  'A cluttered desk with electronics desks and papers': 934,
#  'A toddler happily takes a bite of a donut': 935,
#  'two women sitting at table, while one eats dessert': 936,
#  'A group of people sitting and standing near a car': 937,
#  'A family sits behind the fence at a junior baseball game': 938,
#  'a bathroom with a washer and dryer next to it': 939,
#  'an umbrella a building some signs and a broom': 940,
#  'A police officer walking two bikes next to a geisha': 941,
#  'A white toilet sitting inside of a bathroom stall': 942,
#  'A child in the window of a paper fire truck': 943,
#  'Two young children are playing a video game together': 944,
#  'a man that has a shirt and tie on': 945,
#  'Old picture of tennis player on court with racket': 946,
#  'a guy standing in a snowy forest with his skis off and poles in the snow, preparing to take a picture': 947,
#  'A dog being carried in luggage with rollers': 948,
#  'A tennis player on the court in a tennis stadium with a man walking behind him': 949,
#  'A table with many scissors that have handles of assorted colors': 950,
#  'A male tennis player engaged in organized competition': 951,
#  'A very neat and tidy, fully stocked, kitchen': 952,
#  'An old car is parked in the street': 953,
#  'A blue oval plate is filled with fancy food': 954,
#  'A kitchen has been stripped of small appliances and is being cleaned': 955,
#  'Two zebras stand in front of a gazelle crossing sign at a road': 956,
#  'Two woman stand while holding Wii remote controls': 957,
#  'a street light with a green light next to a street sign and tree': 958,
#  'A dirty kitchen floor with soot on the tiles': 959,
#  'A man flies a kite by the water side': 960,
#  'A baseball player is sliding to one or the bases': 961,
#  'Several skiers on the slop in mid jump': 962,
#  'A double photo of a woman with a tennis racket on a tennis court': 963,
#  'Octagonal "Stop" sign on the road with the smaller sign saying "all the way" underneath it': 964,
#  'Two giraffes standing in the dry African desert': 965,
#  'A bronze fire hydrant has a drawn smiling face on it': 966,
#  'a dude that has a skateboard in hand': 967,
#  'a number of animals in a field near many trees': 968,
#  'A glass of juice sits between two plates of food near pizza hut napkins on a dark yellow tablecloth': 969,
#  'A train traveling down tracks next to a bunch of trees': 970,
#  'A colorful picture taken as birds fly through the forest': 971,
#  'A black motorcycle sitting on the pavement in front of a bush': 972,
#  'A black and white photo of a bunch of people walking along a busy street': 973,
#  'A park at dusk while the sun sets with a bird flying over head': 974,
#  'A bed in a bedroom sitting between two lamps': 975,
#  'A kitchen is shown with a stove and hanging utensils': 976,
#  'a cartoon of a man skiing down a hill': 977,
#  'A full view of a nice and big city': 978,
#  'a person sitting on an ugly red couch': 979,
#  'The pitcher is winding up to make the pitch': 980,
#  'A teddy bear sitting alone in a park or cemetery': 981,
#  'A wheel chair sitting in a living room next to a window': 982,
#  'The emergency vehicles are at the scene of the accident': 983,
#  'Players and officials standing around on an indoor tennis court': 984,
#  'A dog with a curious look lying on the floor of a den': 985,
#  'a living room with many opened windows and curtains': 986,
#  'Three boys playing baseball in a baseball field': 987,
#  'Two ferrets are lying down in opposite directions': 988,
#  'There is a aluminum tray with a large hot dog and fries': 989,
#  'A living room with a couch, a chair and a piano': 990,
#  'A cold dog curled up and going to sleep': 991,
#  'A person crouches with a tennis racket': 992,
#  'A slice of chocolate layered cake on a plate': 993,
#  'A pedestrian area with square stone walkways, benches and trees, along with an elephant statue': 994,
#  'a dog in the refrlection of a car mirror': 995,
#  'A bathroom with a toilet, counter, and mirror': 996,
#  'A wall painted in orange with a toaster': 997,
#  'The outdoor hut contained several beds and fans to keep its occupants cool': 998,
#  'A child smiling as they hold a teddy bear': 999,
#  ...}

# %%
with open("trainval_ans2label.pkl", "wb") as f:
    pickle.dump(ans2label,f)

# %% [markdown]
# ## Training dataset

# %%
df = pd.DataFrame(columns = ["question-id", "image-id", "question", "answer", "labels", "image"])

img_prefix = "/COCO_train2014_"

for question, annotation in zip(questions_train["questions"], annotations_train["annotations"]):
    if question["image_id"] != annotation["image_id"]:
        raise ValueError("Q&A not alligned!")
        
#     print(question)
#     print(annotation)
    filename = train_imgs_path + img_prefix+str(question["image_id"]).zfill(12)+".jpg"
    
    img = Image.open(filename)
    img_buffer = BytesIO()
    img.save(img_buffer, format=img.format)
    byte_data = img_buffer.getvalue()
    base64_str = base64.b64encode(byte_data) # bytes
    base64_str = base64_str.decode("utf-8") # str
#     print(base64_str)
    
    for answer in annotation["answers"]:
#         print(answer)
        
        new_record = {"question-id": question["question_id"], 
                      "image-id":question["image_id"], "question":question["question"].strip().rstrip(".").replace("\t", " "),
                      "answer":'1.0|!+'+answer.strip().rstrip(".").replace("\t", " "), 
                      "labels":"a", "image": base64_str}
        df = df.append(new_record, ignore_index=True)

# %%
df.to_csv("vqa_train.tsv", sep = "\t", header=False, index=False)

# %%
df.tail()
# Out:
#       question-id image-id                         question  \
# 20703      299334   416648  What can be seen in this image?
# 20704      299334   416648  What can be seen in this image?
# 20705      299334   416648  What can be seen in this image?
# 20706      299334   416648  What can be seen in this image?
# 20707      299334   416648  What can be seen in this image?
#
#                                                   answer labels  \
# 20703  1.0|!+A man sitting at a table with boxes of d...      a
# 20704  1.0|!+A man in black sweater sitting at a tabl...      a
# 20705  1.0|!+A older man enjoying a variety of pastri...      a
# 20706  1.0|!+a man cupping his face in his hand holdi...      a
# 20707  1.0|!+a person sitting at a table with boxes o...      a
#
#                                                    image
# 20703  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20704  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20705  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20706  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20707  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...

# %% [markdown]
# ## Validation dataset

# %%
df = pd.DataFrame(columns = ["question-id", "image-id", "question", "answer", "labels", "image"])

img_prefix = "/COCO_val2014_"

for question, annotation in zip(questions_val["questions"], annotations_val["annotations"]):
    if question["image_id"] != annotation["image_id"]:
        raise ValueError("Q&A not alligned!")
        
#     print(question)
#     print(annotation)
    filename = val_imgs_path + img_prefix+str(question["image_id"]).zfill(12)+".jpg"
    
    img = Image.open(filename)
    img_buffer = BytesIO()
    img.save(img_buffer, format=img.format)
    byte_data = img_buffer.getvalue()
    base64_str = base64.b64encode(byte_data) # bytes
    base64_str = base64_str.decode("utf-8") # str
#     print(base64_str)
    
    for answer in annotation["answers"]:
#         print(answer)
        
        new_record = {"question-id": question["question_id"], 
                      "image-id":question["image_id"], "question":question["question"].strip().rstrip(".").replace("\t", " "),
                      "answer":'1.0|!+'+answer.strip().rstrip(".").replace("\t", " "), 
                      "labels":"a", "image": base64_str}
        df = df.append(new_record, ignore_index=True)

# %%
df.head()
# Out:
#   question-id image-id                  question  \
# 0      299336   432397  What this image depicts?
# 1      299336   432397  What this image depicts?
# 2      299336   432397  What this image depicts?
# 3      299336   432397  What this image depicts?
# 4      299336   432397  What this image depicts?
#
#                                               answer labels  \
# 0  1.0|!+A black and white photograph of a plane ...      a
# 1  1.0|!+A crowd of people standing around an air...      a
# 2  1.0|!+An old photo of a crowd of people surrou...      a
# 3       1.0|!+A lot of women standing by an airplane      a
# 4  1.0|!+A group of people crowded around small a...      a
#
#                                                image
# 0  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...

# %%
df.to_csv("vqa_val.tsv", sep = "\t", header=False, index=False)
