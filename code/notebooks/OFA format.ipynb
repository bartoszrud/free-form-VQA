# %%
import json
import pandas as pd
from PIL import Image
from io import BytesIO
import base64
import pickle
import warnings

# %%
warnings.filterwarnings(action='ignore')

# %% [markdown]
# The information of question-id, image-id, question, answer (with confidence), predicted object labels (taken from VinVL, slightly brings around +0.1 accuracy improvement), image base64 string are separated by tabs.

# %%
with open("../questions_validation.json", "r") as f_q:
    questions_val = json.load(f_q)

    
with open("../annotations_validation.json", "r") as f_a:
    annotations_val = json.load(f_a)
    
with open("../questions_training.json", "r") as f_q:
    questions_train = json.load(f_q)

    
with open("../annotations_training.json", "r") as f_a:
    annotations_train = json.load(f_a)

train_imgs_path = "/home/bartek/ETH/CS4NLP/project/train2014"
val_imgs_path = "/home/bartek/ETH/CS4NLP/project/val2014"
# test_imgs_path = "/home/bartek/ETH/CS4NLP/project/train2015"

# %%
def remove_special(input_string):
    final_string = ""
    for character in input_string:
        if  character == " ":
            final_string = final_string + character
        else:
            if(character.isalnum()):
                final_string = final_string + character
#             else:
#                 print("Found ", character)
    return final_string

# %%
ans2label = {}

answers_all = []

for annotation in annotations_val["annotations"]:
    for answer in annotation["answers"]:
        answers_all.append(answer)
#         print(answer)

for annotation in annotations_train["annotations"]:
    for answer in annotation["answers"]:
        answers_all.append(answer)
#         print(answer)

print(len(answers_all))

answers_all = set(answers_all)
print(len(answers_all))
answers_all = [remove_special(answer) for answer in answers_all]
answers_all = set(answers_all)
print(len(answers_all))


for i, answer in enumerate(list(answers_all)):
    ans2label[answer] = i
# Out:
# 30841
# 30598
# 30592

# %%
ans2label
# Out:
# {'A plane is flying over the water and houses': 0,
#  'A nice living room has chairs and a love seat': 1,
#  'A heard of zebra on the plains at a watering hole': 2,
#  'a person that is riding a bike next to some seats': 3,
#  'Several breads and rolls sitting near a toaster': 4,
#  'An angled shot shows a tilted room with pink walls and someones elbow close to a young woman holding part of a sandwich with a tilted table top before her on which rests a napkin': 5,
#  'This man is holding a breadstick and a bun': 6,
#  'Hotel room with shag carpet and a little table on the balcony': 7,
#  'A black duck swimming on top of a body of water': 8,
#  'Two men sitting in red velvet chairs in a ballroom': 9,
#  'A driver and another person pose beside a motorcycle': 10,
#  'Closeup of a yellow fire hydrant on sidewalk': 11,
#  'A group of people with skis posing for a picture': 12,
#  'A wood bench sitting in front of a soft drink display': 13,
#  'People skiing in the snow on the mountainside  ': 14,
#  'A man riding a skateboard into the air': 15,
#  'The person is crossing the street  holding a slow sign': 16,
#  'a sickly pink fishing boat with a mermaid imprint on the side of cabin': 17,
#  'Man standing beside a part custom motorcycle ': 18,
#  'The apartment is clean and ready to be moved in to': 19,
#  'A yellow railroad train pulling into the station': 20,
#  'A woman holding a toddler looking over the gate at a small horse': 21,
#  'A chef cooking with lights on him while he prepares the food ': 22,
#  'Some kites flying over some buildings in the snow': 23,
#  'Two women are talking near table with a cake': 24,
#  'Man makes gang signals as standing on street holding pizza': 25,
#  'These three birds are walking along the beach looking for food': 26,
#  'The red stop sign says stop in two languages there are also cars passing': 27,
#  'A great view can be seen from the top of a doubledecker bus': 28,
#  'A bicycle sits parked in front of a bookstore': 29,
#  'A boy balances a skateboard on a wooden ledge': 30,
#  'A white stuffed teddy bear sleeping on top of a womans bosom': 31,
#  'A very tall building with a pointing roof and a clock on the side of it': 32,
#  'Two suitcases with bags on top of them': 33,
#  'A telephone has it receiver replaced with a banana': 34,
#  'A building has a tower with a spire and at least two faces that sport clocks': 35,
#  'Some big work trucks with guys working on a traffic signal': 36,
#  'two people standing near a food truck on a side walk': 37,
#  'a large intersection with a bike only lane': 38,
#  'A little girl flying a kite on the beach': 39,
#  'A dog sleeping under a blanket on the couch': 40,
#  'A cat with a Christmas hat standing on a carpet': 41,
#  'Two officers at an event with a police dog and horse': 42,
#  'Friends sharing lunch together at an outdoor picnic table': 43,
#  'A Zebra is walking on the ground among bushes and trees ': 44,
#  'Field full of different horses with trees mixed in': 45,
#  'Two zebras on the side of a county road': 46,
#  'A young woman with a pink helmet stops on a motorcycle in the road': 47,
#  'A smiling woman about to eat a hot dog': 48,
#  'A number of surfers near a river with a crowd watching': 49,
#  'a man on a motorcycle that is in some grass': 50,
#  'A boy winds up in tennis to return a hit towards him ': 51,
#  'A small child is wearing a red and gold neck tie': 52,
#  'THIS IS A PICTURE OF YOUNG GIRLS SMILING WHILE SHARING A MEAL TOGETHER': 53,
#  'A beach with lots of people standing and sitting on it': 54,
#  'There is an empty bench by some trees and flowers': 55,
#  'A man on a bike carrying a surf board': 56,
#  'A computer telephone music player and lamp on a wooden desk ': 57,
#  'The young zebra has begun to form his adult stripes ': 58,
#  'A BATHROOM WITH A TOILET SINK AND WINDOW': 59,
#  'A man holding a scissor towards is pony tale': 60,
#  'a bunch of fruit are piled together ': 61,
#  'Two lamps edging flowers and a clock on a table': 62,
#  'A cat relaxes in a suitcase next to a pile of clothes': 63,
#  'A large hotel room has a bed couch and desks': 64,
#  'Mix of different vedgies and meats on toast and salad': 65,
#  'A lion in the wild with a plastic bottle in its mouth': 66,
#  'Two people out in the snow doing cross country skiing': 67,
#  'A burnt skateboard without a wheel sits against a log': 68,
#  'Three personal sized pizzas are arranged on a wooden platter': 69,
#  'People splitting up a box of mixed doughnuts': 70,
#  'Several train tracks with an electric train on one of them': 71,
#  'A very long and bright colored city bus on the street': 72,
#  'The cat sits directly in front of the television': 73,
#  'A couple of beautiful women sitting at a table': 74,
#  'A bench is in front of a flower bed ': 75,
#  'People congregate in front of a truck selling food': 76,
#  'A stack of items that starts with a book and ends with a battery  ': 77,
#  'A kid with a toothbrush in a white sink': 78,
#  'A large crowd standing around a bus station': 79,
#  'Two giraffes standing next to each other in a zoo pen ': 80,
#  'Train cars lined up on rail next to platform': 81,
#  'four small children are skiing down a hill': 82,
#  'Someone holding a wii remote control with the strap around his wrist': 83,
#  'Two street signs sit on top of a stop sign': 84,
#  'a person riding a snow board on a snowy surface': 85,
#  'Large hotel room with a king sized bed and large view of the ocean ': 86,
#  'Two young people setting on top of a big elephant': 87,
#  'A cell phone peeks out of a crocheted cell phone holder': 88,
#  'A log house shows plates a table and dishes on display': 89,
#  'A plate of pasta next to pieces of broccoli': 90,
#  'Men work on the basket of a hot air balloon ': 91,
#  'a woman takes a picture of an open refrigerator door holding soda': 92,
#  'One puppies lies on a bed while another lies on the floor': 93,
#  'A lady is sitting on a bench reading her a book': 94,
#  'a person wearing red tennis shoes and a black cat': 95,
#  'A baseball game takes place on a bright day against a mountain backdrop': 96,
#  'Pizza and pizza paddle laying on a plate': 97,
#  'A picture of a white and black toaster': 98,
#  'A person in a room holding a cat': 99,
#  'Two sidebyside parking meters in front of a parked truck': 100,
#  'Close up view of baked pizza served on table': 101,
#  'The bathroom is decorated with an unusual wall paper': 102,
#  'A woman in the kitchen cooking a meal': 103,
#  'A second baseman trying to catch the ball to tag the player': 104,
#  'A cowed laying down in a fenced in enclosure': 105,
#  'A large jet liner on an airport runway under a blue cloudy sky': 106,
#  'A young woman cross country skis down a path': 107,
#  'Three giraffes standing around inside of their enclosure': 108,
#  'A piece of food is being picked up from the container': 109,
#  'Multicolored Teddy bears arranged in a circular pattern on a table': 110,
#  'A giraffe gets some food from a wood box': 111,
#  'A freight train approaching a rustic water tower': 112,
#  'A man is paddling his own boat with its unique cover ': 113,
#  'Bottles wrapped in plastic stored in a refrigerator': 114,
#  'Four people sitting on a bench looking at the water': 115,
#  'A colorful crown gathers at the waters edge': 116,
#  'a large breed dog laying on a hardwood floor near a sliding glass door': 117,
#  'A zebra laying on the ground with a little girl on top of it': 118,
#  'A disc golf hole with a few men playing near it': 119,
#  'A man playing frisbee with his dog ': 120,
#  'A man leans over a cake that is adorned with lit candles ': 121,
#  'A plate of food has slices of pizza and a bowl of salad': 122,
#  'A stainless steel refrigerator and a hallway leading to another room': 123,
#  'There are two clocks on the wall in the room': 124,
#  'A kitten is lying with half of its body on a laptop': 125,
#  'young woman in board shorts hold a surf board': 126,
#  'there are many snowboarders and skiers gathered ': 127,
#  'a person riding a skate board on a body of water ': 128,
#  'Black and white photograph of a man flying a kite': 129,
#  'A young male child with headphones on is playing on the computer': 130,
#  'A man sitting on a motorcycle on the side of a street': 131,
#  'Two sheep standing next to each other on a  field': 132,
#  'A diorama made of toys depicts a kitchen scene': 133,
#  'An elephant uses its trunk to reach for a snack from someones hand': 134,
#  'A bright pink fishing boat moored in a harbor': 135,
#  'A baseball player wearing a catchers mitt on top of a field': 136,
#  'a black stove in a small home kitchen': 137,
#  'A person sits in the car as the sun is low in the sky': 138,
#  'Two large yellow dump trucks driving down a dirt hill': 139,
#  'A child on a surf board in a fake wave': 140,
#  'Here is a kitten on the keys keyboard that is This longhaired cat is sitting parallel to the top of the keyboard': 141,
#  'A man riding a bicycle down a road with lots of palm trees on its sides': 142,
#  'Black and white photo of two people riding horses': 143,
#  'A person in boots taking off a horse shoe': 144,
#  'There are many doughnuts on the table ': 145,
#  'Man and woman posing next to fence that has giraffe looking over': 146,
#  'A plate with a food made up of different things and a parsley garnish': 147,
#  'Several directional signs mounted on a city building': 148,
#  'Child riding a sheep during a kids rodeo': 149,
#  'A red stoplight with a street in the background': 150,
#  'A large egg sausage and biscuit breakfast sandwich': 151,
#  'A racer on there bike all in uniform ': 152,
#  'four dishes of barbeque food are played on the table ': 153,
#  'A group of bicycles are parked next to a waterway': 154,
#  'Couple of women near pigeons near a busy town': 155,
#  'A person that is sitting on a horse': 156,
#  'A person on a skateboard on a ramp': 157,
#  'People watch multi colored items fly above the beach': 158,
#  'Set of two airplanes sitting in front of a large air port ': 159,
#  'A living room filled with furniture and  set of glass doors': 160,
#  'A motor bike is parked next to a sandy area ': 161,
#  'A little boy holding a can in his hands in front of an open refrigerator': 162,
#  'A man swinging a tennis racket at a tennis ball': 163,
#  'A white llama lying in a field of grass and daisies': 164,
#  'the dinner table with two plates and two glasses of wine': 165,
#  'Various toys medicines and office supplies clutter a desk ': 166,
#  'Someone playing piano behind a fridge a woman sitting by a table with a notebook and a man playing electric guitar': 167,
#  'A catcher kneeling and catching a baseball during a baseball game': 168,
#  'The overhead light and medical equipment on the wall indicate this an operating room ': 169,
#  'Several men playing a video game in a home': 170,
#  'A dog standing on the top of a couch in front of a window': 171,
#  'a room with a desk and a cat in a chair ': 172,
#  'Cat is curled up sleeping on laptop sitting on a bed': 173,
#  'a small propeller plane sits parked in a airfield ': 174,
#  'A woman wearing black and white playing tennis ': 175,
#  'People filling their plates with food out of large pans': 176,
#  'A brown cow standing in a field of dry grass': 177,
#  'a little boy that has a baseball glove in hand': 178,
#  'A blue sea anemone living on a coral reef': 179,
#  'A man sitting at a picnic table having a snack watching a plane fly overhead': 180,
#  'A cat standing on someones lap sniffing an apple': 181,
#  'The toilet has a floral toilet seat and cover': 182,
#  'A person bouncing a tennis ball holding a racket': 183,
#  'Many different pairs of scissors hanging on a wall with prices on them': 184,
#  'Silver spoon in a bowl of oat cereal': 185,
#  'A crowd is watching a baseball game being played': 186,
#  'A woman posing for a photo while petting a baby giraffe': 187,
#  'A group of Zebras grazing in the grass with a truck in the background': 188,
#  'A outdoor area produce market that has bananas hanging from strings and other fruit on tables along with a scale': 189,
#  'There is a building with a clock on the front': 190,
#  'a dog that is eating some kind of cake on a table': 191,
#  'An older woman showing off a cake in a kitchen': 192,
#  'A kid with a baseball bat next to a fence': 193,
#  'A group of people are playing soccer on a soccer field': 194,
#  'Two children eating pizza together and dressed up in costume clothing': 195,
#  'An assortment of flying objects including kites and airplanes hung inside a building': 196,
#  'Bus modified to support a green hippie movement': 197,
#  'The men are on top of the snow covered hill': 198,
#  'A bed that has red white a blue covers and pillows': 199,
#  'a pan filled with broccoli and sausage as well as a wooden spoon': 200,
#  'A person with a surf board at the shore': 201,
#  'a man riding on a skateboard along the edge of a sidewalk': 202,
#  'a collage of photos with a person wearing a suit and tie': 203,
#  'A group of people walking near a cathedral ': 204,
#  'An elaborate entree on a white plate with a glass of water on the side  ': 205,
#  'A bathroom that has a toilet on a tile floor': 206,
#  'A bear sitting down on top of several rocks': 207,
#  'A person is riding a bike down a highway': 208,
#  'A man without a shirt riding a skateboard': 209,
#  'Easy bake oven sitting on top of the original box ': 210,
#  'A brick clock tower has clock faces on two sides': 211,
#  ' A market area with people and many crates of fruit': 212,
#  'A bunch of different kind of items sitting on a table ': 213,
#  'a yellow and white bird is closing its eyes': 214,
#  'A cat sitting on a desk and keyboard with his back towards us': 215,
#  'Getting ready to fly an American flag kite': 216,
#  'A person at the top of a skateboard ramp on a skateboard': 217,
#  'A young woman is flying a kite while standing on the sand at the beach': 218,
#  'A large passenger airplane flying against a partly cloudy sky': 219,
#  'A group of baseball players walking across a lush green field': 220,
#  'Lines of fruits vegetables and grains on a white surface': 221,
#  'a train of many colors is coming down the track': 222,
#  'A large jumbo jet is ascending from an airport runway': 223,
#  'People playing Wii with demonstrators at an electronics convention': 224,
#  'Two zebras lower their heads to the ground to graze': 225,
#  'A street sign mounted on top of a stop sign': 226,
#  'A giraffe near people while looking at the camera': 227,
#  'A giraffe and a zebra in some kind of grassland enclosure with a high wall': 228,
#  'A mobile library bus drives on the road': 229,
#  'Wash basins paper towels mirror and fluorescent light ': 230,
#  'a guy working on a laptop and a desktop in a room': 231,
#  'A person surfing on a wave at the beach': 232,
#  'Slices of pizza upside down on a plate on a table': 233,
#  'A group of women standing around a cake cutting slices': 234,
#  'a soccer team poses for a picture together': 235,
#  'There is a man on the TV screen': 236,
#  'Two women swimming on their surfboards back to shore': 237,
#  'The lady is blow drying the girls hair ': 238,
#  'A young woman scratches her butt under her dress on the tennis court': 239,
#  'A group of people standing on top of a dirt field': 240,
#  'a man with glasses is showing his remote controller': 241,
#  'Three adult giraffes in a zoo like enclosure': 242,
#  'Two men wearing jackets in front of a closet': 243,
#  'a shop with a bunch of signs sitting out front': 244,
#  'A person that is wearing a hat and brushing their teeth ': 245,
#  'A bed covered in black and white blankets': 246,
#  'a professional tennis player at a tennis match prepared to hit the ball ': 247,
#  'A man holding a  tennis racquet near a tennis ball': 248,
#  'A large green metal clock sitting on the side of a building': 249,
#  'A bathroom has a toilet sink and mirror in it': 250,
#  'A bathtub with silver hardware has a digital screen on one side of the wall': 251,
#  'Hot dogs are wrapped in a bacon and topped with melted cheese': 252,
#  'A person kite surfs on a windy river': 253,
#  'At the zoo a brown bear rests its head on a rock': 254,
#  'A group of people riding boars on top of the ocean': 255,
#  'A group of zebras are walking through a field': 256,
#  'A close shot of a peachcolored building with a clock ': 257,
#  'A group of sheep passing in an alley way by a fence': 258,
#  'a vase with some flowers growing out of it ': 259,
#  'A police man on a horse talks to a man with a dog': 260,
#  'A meal at a diner including baked goods and drinks': 261,
#  'Two cows sitting on a beach next to a boat': 262,
#  'A view from a skateboarders board while riding down the street': 263,
#  'A kitchen with a lot of storage space': 264,
#  'The hotdog with mustard and ketchup has a side of french fries': 265,
#  'A soldier is standing on a military vehicle': 266,
#  'a person holding a surf board on a beach ': 267,
#  'Large red bed in room with dresser and futon': 268,
#  'A surf board rider falling off his board while a ship sails out a sea': 269,
#  'A man stands with his hands up while using an interactive video controller': 270,
#  'Snowboarder doing a trick while riding down a halfpipe': 271,
#  'People on boats crowded in the water of a harbor': 272,
#  'A field full of camping tens and a double deck bus': 273,
#  'Motorcycles driving down a wide city street nearing a white building': 274,
#  'Batter taking swing at pitch during major baseball game': 275,
#  'A large pile of a variety of donuts seen from above': 276,
#  'a man is holding a frisbee in his hand': 277,
#  'A bathroom with two urinals placed at different heights': 278,
#  'Two young men riding skateboards on a tennis court': 279,
#  'People standing and sitting on a mountain slope': 280,
#  'The man in the suit is wearing a hat': 281,
#  'A stop sign that is listing to the side': 282,
#  'A commuter train with two engines sitting on tracks': 283,
#  'Two men are flying a kite on a beach in the gravel': 284,
#  'A man in wetsuit surfing on a white surfboard': 285,
#  'A brown bear on rocks with cloudy sky in background': 286,
#  'A train with two engines pulling cars along the curve of a fall photo': 287,
#  'a man directing a plane on an air port run way': 288,
#  'A bison is facing left while standing on a side walk': 289,
#  'Fridge in the corner next to shelves with wine bottles': 290,
#  'There is no image on display to describe': 291,
#  'All of the food on the plate and the glass of beer are very unhealthy': 292,
#  'A man holding up a hair dryer toward clothes': 293,
#  'a pole with a street light sitting on top of it ': 294,
#  'A man laughing as he talks into his cell phone': 295,
#  'A small plane flying over a body of water': 296,
#  'A group of people riding paddle boats on top of blue water': 297,
#  'Teddy bears are on display beneath a travel necessities sign': 298,
#  'A large giraffe standing in front of a lush green wilderness': 299,
#  'A woman in white shirt walking a dog in forest': 300,
#  'a bunch of flowers that is around a house': 301,
#  'A SMALL GARDEN WITH A WOOD OUT HOUSE AND BENCH ': 302,
#  'A stainless steel kitchen with black countertops and wooden cabinets': 303,
#  'Kite flying Washington DC with Smithsonian and Washington Monument in background': 304,
#  'A tan and browncolored living room with TV and fireplace': 305,
#  'A man holding a banana a sign that reads bath time fun': 306,
#  'Pink lilies arranged in a white ceramic vase': 307,
#  'A Gold fish sticker logo on a laptop': 308,
#  'Men are playing a game of outdoor frisbee': 309,
#  'A kitchen that is full of utensils and items': 310,
#  'A large truck is driving down a road': 311,
#  'A white vase holding flowers with a window in the background': 312,
#  'A boy holding his bat next to a tball stand': 313,
#  'A cat lying on a large flat pillow': 314,
#  'Snowboarder on a snowy hill surrounded by trees': 315,
#  'A grey and white cat laying in a black wire basket': 316,
#  'A man with a tennis racket in his hand ': 317,
#  'A set of miniature appliances for a kitchen which also have miniature pots and pans': 318,
#  'There is a bunch of bananas in a basket': 319,
#  'Water is washing gently on to the sand': 320,
#  'a clay pot vase of red flowers on top of a refrigerator': 321,
#  'Many people on a courtyard under a clock': 322,
#  'A halffilled drinking glass on a table near books and a television remote control': 323,
#  'a man is about to crash after riding on a skate board ': 324,
#  'Three men load wood onto a large train': 325,
#  'A woman holding a skateboard on the sidewalk': 326,
#  'A woman standing and smiling at camera wearing hat and raincoat and holding a paper cup in hand with two brightly multicolored birds perched on her lower bent arm and one bird on her shoulder': 327,
#  'A lady in a bikini on the beach is flying her kite ': 328,
#  'Street signs showing the intersection of two streets ': 329,
#  'a person sitting on a bench with their head crouched over': 330,
#  'a laptop sitting on a big blue box': 331,
#  'Three people are out on the sand and one child is holding a kite while the other young one is running and a man is holding the kite string': 332,
#  'An old photo of a clock sitting on a mantle': 333,
#  'a piece of pizza sitting on a white plate': 334,
#  'An orange cat laying in a piece of luggage': 335,
#  'A small girl laughing while holding a hair dryer': 336,
#  'A kitchen with an open pantry and some empty glass bottles on the counter': 337,
#  'A metal sink sitting inside of a kitchen': 338,
#  'A policeman on a motorcycle behind a van': 339,
#  'a man standing in front of a fireplace and pointing ': 340,
#  'nine boats docked at a marina with old buildings in the background': 341,
#  'An uncooked pizza sits on the counter ': 342,
#  'a woman in the kitchen cooking some food': 343,
#  'Girl with green an black ribbons in hair with tie and goggles': 344,
#  'A clock tower painted in white blue and green': 345,
#  'a living room with some couches and a dinning table ': 346,
#  'A woman walks on the street under a yellow umbrella ': 347,
#  'Airplanes parked in the evening at an airport ': 348,
#  'A group of cows resting on one another': 349,
#  'a close up of a piece of cake on a plate ': 350,
#  'Adults playing with frisbees in a verant park': 351,
#  'a couple people that are walking on a beach': 352,
#  'a woman waring a beanie is on a coach': 353,
#  'A shack right next to the beach ': 354,
#  'A crowd of people gathered at the Lock': 355,
#  'white and orange trains on a railroad passing through a city': 356,
#  'a man with his thumb up as he eats a slice of pizza': 357,
#  'A motorcycle parked nest to rail near the ocean': 358,
#  'A man in a hat sits down with a plate of cake': 359,
#  'I women sitting at a table with a large amount of food in front of her': 360,
#  'A woman in a blue shirt is in a court yard': 361,
#  'Lonely kettle rest on top of the oven': 362,
#  'A painting of a colorful vase filled with flowers': 363,
#  'There is a kitchen with black counters and appliances': 364,
#  'The group of people are watching the dog play with his Frisbee ': 365,
#  'A large herd of sheep are gethered inside together': 366,
#  'Woman smiling holding utensils cutting salad on table': 367,
#  'A pizza that is on a wooden platter': 368,
#  'A baseball player in white swinging at a baseball ': 369,
#  'A messy baby eating in a baby seat': 370,
#  'there is a man and a woman that are playing a video game ': 371,
#  'Commercial jet possibly Singapore Air in flight overcast skies': 372,
#  'A picture of a birthday cake all lit up': 373,
#  'Pigeons attempt to eat pieces of pizza on the ground': 374,
#  'The contents of a purse are laid on the floor beside it': 375,
#  'An international air plane on a runway strip': 376,
#  'Utensils and containers line the sink in a kitchen': 377,
#  'Three slices of pizza sitting on top of a wooden cutting board': 378,
#  'a close up ofa cup of ice cream and bananas ': 379,
#  'A man stands at a table on his phone with blurry people in the foreground': 380,
#  'A group of people sitting at a table': 381,
#  'A large vehicle drives down the road by a building': 382,
#  'A man with short sleeves and a hat standing next to a cow in high grass': 383,
#  'A market with many varieties of fruit and shoppers': 384,
#  'A man that is sitting down with his mouth open': 385,
#  'A wide variety of baked goods behind a bakery counter': 386,
#  'A little boy sitting next to a little girl holding plates of food': 387,
#  'Two people playing baseball in a fenced in area': 388,
#  'A view of a couple pieces of sushi and apple slices': 389,
#  'Skiers skiing down a snow covered ski slope': 390,
#  'Three people on a ski slope with big trees': 391,
#  'A bus with free wifi driving in the wet road': 392,
#  'A man skiing across snow covered ground on skis': 393,
#  'People mulling around the inside of a bookstore': 394,
#  'A traffic signal at the end of a tree lined road': 395,
#  'Two children are playing soccer in a large field': 396,
#  'a close up of many small vases with flowers in them': 397,
#  'A man skiing high on the mountain side': 398,
#  'a television sits on top of a stack of books ': 399,
#  'A corner of a bedroom with a lamp a bed and two wall hangings': 400,
#  'A man wearing a suit and tie walking down the street': 401,
#  'A man holding a drink and his luggage by a train': 402,
#  'A black and white photo of a woman playing tennis': 403,
#  'A zebra is grazing in the grass near rocks': 404,
#  'A bedroom area with bed shelves and a nightstand': 405,
#  'There are many people skiing on the snowy mountain': 406,
#  'These are the paws of a sleeping cat': 407,
#  'Some muffin like food that is on a plate': 408,
#  ' Plates of food and beverages on a table': 409,
#  'Group of people riding on horseback and for the ocean ': 410,
#  'A man on a beach getting ready to throw a frisbee': 411,
#  'A beach filled with lots of people standing next to each other': 412,
#  'a passenger airplane at an airport with a car': 413,
#  'A woman smiles as she holds a remote control for a video game': 414,
#  'there is a dog that is sitting in the drivers seat of a car': 415,
#  'Snowboard stuck in a thick collection of trees ': 416,
#  'Several sheep are seen roaming the hills with mountains in the back': 417,
#  'A white city bus is parked on the edge of a street': 418,
#  'A long white passenger train traveling through lush green countryside': 419,
#  'A white cat with spots on its face sitting on a microwave oven and looking forward': 420,
#  'A bird sitting on top of a tree branch filled with leaves': 421,
#  'A young business woman holds her brief case while looking at the camera': 422,
#  'A woman holding a glass of wine in her right hand': 423,
#  'Various kinds of cupcakes on display on the counter': 424,
#  'A fighter jet is flying at a fast speed': 425,
#  'A blurry photo of a bicycle passing by a bench': 426,
#  'A bunch of antique cars are being displayed in grass': 427,
#  'a skate boarder coming down a high slope': 428,
#  'A midsized plant with leaves of varying colors': 429,
#  'person doing skate tricks as people watch  him': 430,
#  'A pretty tennis player in action on the court': 431,
#  'A woman is driving along and smiling as she passes through a tree lined area': 432,
#  'a bike standing up on the ground next to a tree': 433,
#  'A large building with a clock tower in the center of it': 434,
#  'Surfer riding a wave just braking performing manuever': 435,
#  'a group of men in red coats ride horses down a street': 436,
#  'Two young beautiful women sitting on a curb next to a street': 437,
#  'a man using a tool to write a love note on the sidewalk ': 438,
#  'A soldier on the flight deck of an aircraft carrier as a jet arrives': 439,
#  'A man carrying a red bag of luggage': 440,
#  'Little boys are in a boat with bananas and drinks ': 441,
#  'An airplane museum in Arizona spread out against the mountains': 442,
#  'Cutting into an open faced sandwich topped with garden vegetables': 443,
#  'A Siamese cat standing toward the rear of a busy desk in back of a pair of open laptops with a slatted window behind it': 444,
#  'A skater outside his school on a chilly late afternoon': 445,
#  'two sheep laying down on a field of green grass': 446,
#  'Two boats are sitting her in front of a break wall ': 447,
#  'A group of people are standing outside next to a plant': 448,
#  'A woman getting a ticket from a parking meter': 449,
#  'there are two men standing on the tennis court ': 450,
#  'Several people walking near several building during the day ': 451,
#  'Rows of unripe bananas on display in a store': 452,
#  'A dog stands in the foreground with a truck and camper in the background': 453,
#  'two plastic containers filled with some silverwards and some toothbrushes': 454,
#  'Large amounts of food layed out buffet style and people serving themselves': 455,
#  'Three men are standing in a parking lot': 456,
#  'A nice looking pizza is on a white plate': 457,
#  'a large clock resting on a poll by some trees': 458,
#  'A plain white bathroom with a sink and a tub': 459,
#  'A group of people is cutting a cake together': 460,
#  'A book laying open on a table with a stack of books and a electronic reader ': 461,
#  'The modern computer has been decorated with wood': 462,
#  'a striped couch a picture a clock a mirror a plant and a lamp': 463,
#  'The view into a living area with couches and a large television ': 464,
#  'One of the parking meters has been knocked off its pole': 465,
#  'A cat sitting on a log in the middle of a wood': 466,
#  'A woman swinging a racket at a tennis ball': 467,
#  'two citit buses parked in the street outside buildings': 468,
#  'A bench on a sidewalk in a park': 469,
#  'Elephants stand together in the grass near the trees ': 470,
#  'People are having a good time in this photo': 471,
#  'Young child making a face having to eat her vegetables': 472,
#  'a man in a yellow shirt standing next to a pedestrian sign': 473,
#  'a tennis player swinging a racket on a court ': 474,
#  'An oncoming blue and yellow train next to a fence ': 475,
#  'a woman holding onto a piece of pizza with her mouth ': 476,
#  'a group of people are riding by on motor bikes': 477,
#  'A little kid standing next to a toilet': 478,
#  'The flowers make the table look nice ': 479,
#  'There is a young man in a commercial kitchen opening the door of some culinary equipment ': 480,
#  'A piece of cake and a cup of coffee atop a blue tray': 481,
#  'Vintage black and white class picture probably from boys school': 482,
#  'A group of women riding on the back of a motorcycle': 483,
#  'A pizza in a pan on t a stove with a plate nearby': 484,
#  'A man is playing a video game while a little girl watches': 485,
#  'motorcycle bikes all parked next to each other lined up down the road  ': 486,
#  'Large elephant sitting in a body of water with two men standing in front ': 487,
#  'A couple of cats sitting on top of a skateboard': 488,
#  'Bear cubs play among the fallen tree limbs': 489,
#  'a group of men playing in a grassy field with a frisby': 490,
#  'a large neatly made bed with a cat on the ground': 491,
#  'A dog holding a yinyang symbol kite in a field': 492,
#  'A large Delta passenger plane sitting on an airport tarmac': 493,
#  'Friends playing with a Frisbee in a green field': 494,
#  'A pair of conjoined stalls in a public restroom': 495,
#  'A dark street with many store lights turned on ': 496,
#  'A group of cars parked in front of a building with arches': 497,
#  'A little girl wearing pink pants and a purple sweater': 498,
#  'A girl is getting ready to surf on a wave': 499,
#  'A stop sign on a pole on a street corner': 500,
#  'A person holding up a smart phone in front of a singer': 501,
#  'A picture of three different chocolate dishes and drinks': 502,
#  'There is a store window advertising that it is a cake shop': 503,
#  'A vase filled with roses next to lit candles on a table': 504,
#  'A group of planes flying in the air': 505,
#  'A female applying icing on a cake at home': 506,
#  'A baby cow and a large cow standing next to each other ': 507,
#  'a street sign with a building in the background': 508,
#  'a little girl balancing a tennis ball on a racket': 509,
#  'A glass of orange juice and a teddy bear sitting on a table outside': 510,
#  'A man has his hand on top of a blender': 511,
#  'an older woman standing near a clock on a wall': 512,
#  'Several zebras who are wandering around and in water': 513,
#  'a beautiful hawk on top of a building': 514,
#  'A guy is standing near a vase of flowers and he is wearing a striped tie': 515,
#  'Two men riding their horses on a grassy hill with sheep in the background': 516,
#  'Two people in neon vests riding horses down the beach': 517,
#  'A red stop sign sitting on the side of a street': 518,
#  'A smiling man holds a doughnut with smiling women next to him ': 519,
#  'A man is playing tennis and is getting ready to serve': 520,
#  'a glass window with a clock behind it and trees reflected in the glass': 521,
#  'A black kit flies in the sky over a body of water and hills are in the background': 522,
#  'A herd of cows that are walking on the beach': 523,
#  'There is a eloquently decorated Christmas tree in the foyer': 524,
#  'A field full of various motorcycles parked beneath willow trees': 525,
#  'A woman that is laying down with a dog on a couch': 526,
#  'People are in a restaurant holding up pizzas ': 527,
#  'A pizza with meat on a table next to a beer ': 528,
#  'A black cat sitting on a bench in the park': 529,
#  'A brown dog standing on grass with red car in the background': 530,
#  'A plate with many small sandwiches and a leaf ': 531,
#  'A man on a skateboard that is on the sidewalk': 532,
#  'a man is doing a trick on a skateboard in a ramp': 533,
#  'A guy in a black outfit stands at a crosswalk looking to his left ': 534,
#  'A man on a telephone near an exposed wire box': 535,
#  'Man poses for picture with his dog while sitting on a bench': 536,
#  'A man wearing glasses riding a train and reading a book': 537,
#  'A painting of seagulls flying in the blue sky with their wings spread': 538,
#  'The view of a restroom with a toilet and washer and dryer combo': 539,
#  'a large building leafless trees and a fountain': 540,
#  'A man on a snow board high in the air': 541,
#  'A red and yellow train car sitting in a train yard': 542,
#  'A wooden bench is out in nature on a nice day': 543,
#  'A boy playing tball wearing a helmet outside': 544,
#  'A pair of planes sitting on an airstrip next to cones': 545,
#  'A man riding a horse drown carriage driving across a field': 546,
#  'Two dark horses are standing under cloudy skies': 547,
#  'The cruller is on the  paper served  with Dunkin Donut coffee': 548,
#  'Seven potted pink flowers on a marble counter': 549,
#  'A commercial passenger jet flying in the air': 550,
#  'A boat at dock with the motor still running': 551,
#  'Young male adult in mid air on his skateboard': 552,
#  'A girl leaning on a statue on a bench outside of a museum': 553,
#  'Two young girls work together to decorate a cake': 554,
#  'A pile of different types of vegetables on top of each other': 555,
#  'a orange bus that is on a concrete street': 556,
#  'Stop sign on street with car in the distance': 557,
#  'Two children standing in a room playing games': 558,
#  'A cat is sitting on top of a silver microwave': 559,
#  'Playing tugofwar with a Frisbee with evidence of previous chewing action': 560,
#  'There is a little girl eating a piece of cake': 561,
#  'Two sheep in a pasture one has been sheared': 562,
#  'A dog playing with a sheet in its mouth as the camera flashes light on its eyes': 563,
#  'A man holding a baseball bat over his shoulder in front of a crowd': 564,
#  'A tennis player prepares to return the ball ': 565,
#  'Three microwave ovens sitting on a table ': 566,
#  'Three service members are cutting a cake together': 567,
#  'An elderly couple are hugging on a bench': 568,
#  'Three people sitting on their motorcycles near a building ': 569,
#  'a person riding a snowboard soaring thru the air': 570,
#  'light brown cocker spaniel dog howling in street': 571,
#  'A group of pigeons walking on stone ground near a park bench': 572,
#  'A shower over a bath tub and a toilet': 573,
#  'a little clock tower standing in the middle of the road ': 574,
#  'A man on a horse that is walking during the day': 575,
#  'A crowd of people demonstrating with police walking with them ': 576,
#  'People eating and making hot dogs on a grill': 577,
#  'A vintage photo from the 1950s of a small town street lined with parked cars': 578,
#  'Three people play a game with a Frisbee in a grassy area': 579,
#  'A bottle of wine next to a carafe and a slice of pizza on a plate': 580,
#  'a really large building with a airplane flying over': 581,
#  'The two signs show the speed limit around a curve': 582,
#  'Screaming man in a business suit with both hands on his face': 583,
#  'A wooden bench in front of a body of water with boats in the water': 584,
#  'Two ferrets are lying down in opposite directions': 585,
#  'A person on snowboard with a ski lift in the background': 586,
#  'a close up of a keyboard a mouse and a lamp': 587,
#  'A motorcyclist with helmet and neon vest taking a photograph in side mirror': 588,
#  'A group photo from the 1960s of teenagers in suits and dresses': 589,
#  'A man and woman kissing under an umbrella': 590,
#  'The table has two wine glasses a bottle of wine and a vase sitting on it': 591,
#  'Cargo train is traveling on a track next to a forest ': 592,
#  'A pair of parking meters are shown placed next to each other': 593,
#  'The baby boy is getting ready to have pizza for lunch': 594,
#  'Interior of bathroom with tub and sliding glass divider and dark tile': 595,
#  'A man skiing down a slope under a blue sky': 596,
#  'A bus drives alongside a truck on a street ': 597,
#  'A large jetliner flying over a mountain next to a statue of Jesus': 598,
#  'A woman in red shirt and white skirt playing tennis': 599,
#  'A group of people walking on top of a sandy beach': 600,
#  'A woman wearing a tiara cutting a cake while two men sit behind her': 601,
#  'A sheep standing on a hill in the middle of a field': 602,
#  'The bulldog is sitting inside the travel bag': 603,
#  'A bedroom comforter set that is white and blue': 604,
#  'A truck with a police sticker is shown in front of a building': 605,
#  'A dog sits in front of a table of supplies': 606,
#  'an orange placed on a fir tree branch': 607,
#  'The inside of a white bathroom with a pink floor mat': 608,
#  'Two sugared doughnuts in a wooden bowl on a counter': 609,
#  'A cake with the number 35 spelled out with candles': 610,
#  'a black dog nibbling on a blonde womans hair ': 611,
#  'A man with a helmet on sitting on a motorcycle while people watch ': 612,
#  'An airplane is parked on the runway at an airport': 613,
#  'Three white plates sitting on top of a table': 614,
#  'Soccer players contending over ball during a match': 615,
#  'A young boy with spiked hair on a skatebaord': 616,
#  'Photos of two ferrets sleeping in a pet bed': 617,
#  'A bucket of carrots are sitting in the kitchen': 618,
#  'A white plate with chicken and mushrooms with rice': 619,
#  'a person laying in a bed with anther person standing': 620,
#  'A fire hydrant spraying acroos an empty street': 621,
#  'A man in a green shirt and a woman in a white shirt on a bench': 622,
#  'a yellow and black train traveling along a train track': 623,
#  'A lone bench sits near a late on a cloudy day': 624,
#  'A relaxing cat lies next to a keyboard ': 625,
#  'a brown cow rests between two parked motorcycles': 626,
#  'An umpire catcher and batter are playing baseball': 627,
#  'A man in white shirt jumping onto a skateboard': 628,
#  'A man and a woman ride a motorcycle down a street': 629,
#  'Two people at the top of a mountain ready to head downhill on skis': 630,
#  'Two guys are watching tv in the living room': 631,
#  'Two snowboarders stopped at the top of a mountain ': 632,
#  'A lot of zebras standing in the sand on a hot summer day': 633,
#  'This looks like a happy guy wearing a tie': 634,
#  'A man sitting on a bed in front of two laptop computers': 635,
#  'A man posing for a picture between two women ': 636,
#  'A parking meter thats full of graffiti and junk': 637,
#  'two little birds standing on the ground by some leaves': 638,
#  'A young man swinging a bat towards a ball': 639,
#  'A poor looking kitchen has a man stirring a big pot': 640,
#  'Landing strip with two planes several men and an SUV': 641,
#  'a plate with a piece of meat and some grape fruits': 642,
#  'A para sailor travels on a body of water ': 643,
#  'A stationary train sitting on display on the tracks': 644,
#  'Two hands one with a ring hold an electronic gadget': 645,
#  'A double decker bus driving down the street': 646,
#  'A group of people walking on top of a rocky hillside': 647,
#  'A flock of birds flying high over a city street at dusk or dawn ': 648,
#  'A person wearing a snow suit coming down a hill on a snow board': 649,
#  'Many donuts are sitting on a wooden counter ': 650,
#  'A bunch of apples on display in a store': 651,
#  'People are sitting on bikes on a dock': 652,
#  'A guy standing in a small field with a big city behind him': 653,
#  'A woman in a black leather jacket hugging a large black suitcase': 654,
#  'A bird sits on a tree branch in the day time': 655,
#  'The back of an airplane flying in the air ': 656,
#  'A boy in red shirt grinding a skateboard on a stair': 657,
#  'a book and a tablet on a black desk': 658,
#  'A man on a horse with several pack horses and a dog behind a very large flock of sheep on the road': 659,
#  'Two glasses of milk sitting on top of a table': 660,
#  'A bird that is sitting on top of a tree': 661,
#  'Skiers get ready to ride down the mountain': 662,
#  'Passengers wait to board a commuter train at a station': 663,
#  'A tennis player casts a short shadow as he runs for the ball': 664,
#  'a man putting two uncooked pizzas into an oven': 665,
#  'A red rose is in a clear vase halffilled with water': 666,
#  'Several baseball players playing a game of baseball': 667,
#  'A pizza on a grill with many veggies ': 668,
#  'A woman is holding a Frisbee in her hand': 669,
#  'The clock tower has been placed at the end of the bridge': 670,
#  'People standing on a platform in front of a train': 671,
#  'A picture of three race horses nose to nose to nose': 672,
#  'A train is either coming or going to a trainstop': 673,
#  'A kitchen counter with vegetables sitting on top of it': 674,
#  'A man is sitting in a cubicle holding a television remote': 675,
#  'A person slicing a piece of food with a pizza slicer': 676,
#  'a sheep with a tag placed on its ear ': 677,
#  'A woman carrying a purse and furled umbrella walking down a busy city street': 678,
#  'a pitcher on the mound having just released a pitch': 679,
#  'A black and white photo of someones feet on top of a skate board': 680,
#  'A teddy bear with a pacifier and a baby bottle': 681,
#  'The ripe bananas are sitting in the brown basket': 682,
#  'Man with suitcase standing in red alley alone': 683,
#  'A man riding a skateboard through a pavilion': 684,
#  'A group of officers riding horses on street next to cars': 685,
#  'a bird that is standing on some kind of pole': 686,
#  'a woman swinging to hit a tennis ball': 687,
#  'One elephant wading in a pond and the other one keeping watch': 688,
#  'Two lanes of cars waiting at a red light': 689,
#  'A fridge microwave and sink in the kitchen': 690,
#  'Two men and a woman talking at a table with a laptop': 691,
#  'A man crouching near an jet on a runway': 692,
#  'Baseball players posing for a picture before a game': 693,
#  'A very close look of a griddle with some hot dogs on it ': 694,
#  'A table full of boxes and plates of pizza': 695,
#  'Older black and white photo of a woman playing baseball and swinging a bat': 696,
#  'Suitcases revolving around on an airport baggage belt': 697,
#  'A woman sitting in a chair in town while looking at her cell phone ': 698,
#  'A man with camera watching a group of giraffes': 699,
#  'A gray van parked outside of an orange building': 700,
#  'A pack of skiers are lined up to start a race': 701,
#  'The man is getting ready to throw a frisbee': 702,
#  'two cats sitting on a window sill with large windows': 703,
#  'A womans foot in a ballet flat next to two pieces of luggage': 704,
#  'The fire hydrant is on the sidewalk near the grass': 705,
#  'A corner of a very small rest room with a pretty sink': 706,
#  'Two giraffes walking next to each other in an open field ': 707,
#  'A person standing on a surfboard riding waves': 708,
#  'A stunt skate boarder is performing stunt on a ramp of a skate park': 709,
#  'Two brown and white cows standing on the shore': 710,
#  'Small little girl flying a kite on the beach ': 711,
#  'A large elephant standing next to a bunch of trees': 712,
#  'A train engine moving down the tracks in the snow with a tree line behind it': 713,
#  'people gathered around standing and sitting on a yellow and blue looking box': 714,
#  'a box of six donuts some with frosting and sprinkles ': 715,
#  'A pizza that is sitting on a counter': 716,
#  'A clock on a sidewalk near stores and benches': 717,
#  'Picture of snow Innetowne with cars traveling slowly': 718,
#  'Guy takes a picture of himself through trucks side view mirror': 719,
#  'A garbage truck in a city warns people to watch for workers behind the vehicle': 720,
#  'an elderly man at a wine tasting area': 721,
#  'A cat laying on top of a paper plate': 722,
#  'A hamster in a glass container with a piece of broccoli ': 723,
#  'A group of people are standing around in a room with a tv': 724,
#  'Some cows are laying down and some are standing eating grass in a meadow with plenty of trees': 725,
#  'A cow walking in the sand on a beach': 726,
#  'A toddler is brushing his teeth with his green brush ': 727,
#  'A man is sitting on a motorcycle with a helmet with other men in uniform on motorcycles behind them': 728,
#  'A baby girl sitting on a blanket holding a teddy bear': 729,
#  'older man reading a bicycle on the street': 730,
#  'Half dozen doughnuts displayed by worker in cardboard box': 731,
#  'A little girl standing behind a wooden fire truck': 732,
#  'A toilet seat which is dirty and appear to be broken': 733,
#  'bagged scissors and color rocks set on a box': 734,
#  'A man on a skateboard at a skate park ': 735,
#  'Man skiers make their way down a snowy ski hill': 736,
#  'A woman kneeling on the floor using a food processor': 737,
#  'Black and red train moving along its train tracks': 738,
#  'Motorized scooters parked at the beach in front of some palm trees': 739,
#  'The bird is perched on a white rock': 740,
#  'A man riding a wave on top of a surfboard in the ocean': 741,
#  'A group of young boys and girls having plates of food at a table': 742,
#  'there is a baseball that has swung to hit the ball': 743,
#  'The bench is in the front yard next to two chairs ': 744,
#  'Eight trolley that is going by a house': 745,
#  'a woman poses with a hot dog to her mouth': 746,
#  'a double Decker bus that is parked on a road': 747,
#  'A boy is surfing a wave on a surfboard': 748,
#  'A clock is above a table and chairs': 749,
#  'Apples and applesauce are sitting on a white doily': 750,
#  'An Olympic skier heading down the slopes avoiding obstacles': 751,
#  'A plane flying over bright blue water near an island': 752,
#  'Intersection of two streets with a stop sign and trees': 753,
#  'Several players in a mid air jump competing for a Frisbee': 754,
#  'A zebra lying on its back on the ground': 755,
#  'Woman serving the ball during a personal tennis game': 756,
#  'A  city bus with bikes on the front of it': 757,
#  'Several carrots sitting in a plastic container on a counter': 758,
#  'Black and white photo of a potfilled stove in a kitchen': 759,
#  'Two different vintage pictures of people doing skateboard tricks': 760,
#  'an elephant standing on a city street next to people with a bunch of bananas ': 761,
#  'a kid in a yellow shirt with a baseball glove': 762,
#  'A person with a surfboard walks along a beach': 763,
#  'A man falling off a surfboard while riding a wave in the ocean': 764,
#  'a person that is standing up holding a snowboard': 765,
#  'A large group of people watching a television screen': 766,
#  'A ticket booth that looks like an elephant ': 767,
#  'Gloves cell phones brushes ties and ear buds are placed on the floor ': 768,
#  'THERE IS A HORSE THAT IS IN THE STREET ': 769,
#  'A red double decker bus is going down a city street': 770,
#  'One bus travels down a street while another is parked': 771,
#  'Three skaters are about to skate through a ramp': 772,
#  'The people are playing tennis in the gym': 773,
#  'Three adults riding on top of an elephant swimming': 774,
#  'a person laying in a bed under the covers': 775,
#  'Asian guy holding a plate of pickles inside a resturant': 776,
#  'The small bathroom is decorated in black and white': 777,
#  'a close up of an unidentifiable orange item with small squares of cheese': 778,
#  'A large white bear walking across a river': 779,
#  'A bunch of doughnuts that are sitting on a plate': 780,
#  'Cows seen before a majestic misty green mountain ': 781,
#  'Two people play a game on the Wii ': 782,
#  'A bright yellow plate holds a chicken sandwich and sweet potato fries': 783,
#  'A guy on a surfboard in the ocean riding a wave': 784,
#  'A fluffy cat laying on top of a white laptop computer': 785,
#  'A black table topped with a vase filled with flowers': 786,
#  'A large clock tower is next to a tree': 787,
#  'a pizza with some tomatoes on it as a topping ': 788,
#  'a man holding onto a kite with an american flag pattern on it': 789,
#  'two people walking near a person using a cell phone ': 790,
#  'an elephant outdoors next to a brick wall': 791,
#  'A woman in purple pants stands next to a metal item': 792,
#  'The intersection of a city street at a red light ': 793,
#  'A busy street scene with cars and pedestrians': 794,
#  'A man sitting on a couch with a laptop': 795,
#  'An adult on a fenced tennis court with tennis racket in hands aimed at tennis ball in air': 796,
#  'A white apple computer monitor sitting on top of a table': 797,
#  'a polar bear playing with a toy in the water': 798,
#  'two police officers in green jackets sitting on horses': 799,
#  'A sheep that is laying down in the dirt': 800,
#  'the white wing of  plane some clouds and some land': 801,
#  'A woman having a drink while wearing an ID badge': 802,
#  'A giraffe walking through the grass towards a wall': 803,
#  'a plate of food with some different types of food': 804,
#  'A pasta dish with spinach and meat in a bowl': 805,
#  'A One Way sign is posted on top of a Stop sign': 806,
#  'A bus sitting at a bus stop in a city square': 807,
#  'Four people three electronic devices a little conversation': 808,
#  'A person is jumping across some water on a ski': 809,
#  'A man holds on tight as he rides across the water': 810,
#  'a bottle and a glass on a white table cloth': 811,
#  'A group of people sitting at desk in front of laptop computers': 812,
#  'A sink sitting in a  kitchen under a cupboard': 813,
#  'A photo of a man swinging his racket to hit a tennis ball': 814,
#  'A large statue of a red chair with a horse on the seat': 815,
#  'A donkey leads a herd of sheep down a busy street': 816,
#  'A man cutting an apple with a pocket knife': 817,
#  'A man eagerly stuffing a cheesy hot dog into his mouth': 818,
#  'A man that is cutting something into smaller pieces': 819,
#  'A television that is on a entertainment stand': 820,
#  'A baseball player standing in a field with red shoes': 821,
#  'Model in businesswear carrying a briefcase posed in front of a wall of maps': 822,
#  'a small laptop and big laptop next to each other on a table': 823,
#  'this is a sandwich on a plate with bread': 824,
#  'Woman standing in middle of room with a green and white stripped dress': 825,
#  'Three cows chilling on the sand next to a beached boat': 826,
#  'Broken glass rusty nails and tools lie on a piece of cardboard': 827,
#  'A white toilet and sink in a green tiled bathroom': 828,
#  'A white dog running on a grassy pathway': 829,
#  'It seems here something is really amazing with many things to see ': 830,
#  'a baseball player slides into a base and is tagged by a glove': 831,
#  'A hand holding a camera with a small viewfinder screen': 832,
#  'A sandwich salad and water on a tray': 833,
#  'a male and a female riding on a white and black motorcycle and cars': 834,
#  'A family sitting at a dinner table with bowls of soup': 835,
#  'A women who is swinging a tennis racket': 836,
#  'a close up of a stop sign with many stickers ': 837,
#  'A baseball player holding a bat getting ready to swing': 838,
#  'A woman wearing a pink fury hat is walking': 839,
#  'girl at a restaurant table loaded with food': 840,
#  'Woman sitting with a dog on a couch in an entertainment room': 841,
#  'People riding motorized bikes speed by on a rainy street': 842,
#  'The adult giraffe stand near a stone wall': 843,
#  'Two bowls of lemons setting on a shelf': 844,
#  'A girl in an open area preparing to throw a frisbee': 845,
#  'As a baseball game is happening people are observing ': 846,
#  'Seeds set out to sprout are identified by popcicle sticks': 847,
#  'Two giraffe in a cage laying in a green field': 848,
#  'the child with the red helmet is riding a sheep': 849,
#  'A man sitting on top of a bench next to a woman': 850,
#  'Two jockeys race horses down a grassy track': 851,
#  'A boy holding a cell phone to his ear while looking up ': 852,
#  'A small old fashioned television that is sitting on the back of a bar': 853,
#  'A white refrigerator freezer sitting in a kitchen': 854,
#  'A pitcher in baseball in the process of throwing a pitch': 855,
#  'A beautiful large head of Broccoli in a garden': 856,
#  'Four people dressed in animal costumes holding large suitcases': 857,
#  'A woman uses a laptop computer to look at pictures of people playing tennis': 858,
#  'A train that is going by some houses in the day': 859,
#  'A large building with a clock on the front of it': 860,
#  'A doubles match is played on a tennis court': 861,
#  'a large jet airplane with its nose pointing up in the air': 862,
#  'a close up of a bed with pillows and sheets': 863,
#  'A bathroom with wooden floors and a red towel ': 864,
#  'a car with a bike strapped on the trunk': 865,
#  'Two women having a drink next to a fire': 866,
#  'a woman is standing in the kitchen winking': 867,
#  'Several men in the middle of a baseball diamond ': 868,
#  'A young man riding a wave on a surf board': 869,
#  'A large elephant can be seen in an enclosure commonly seen at a zoo': 870,
#  'there is a vintage train coming up the tracks': 871,
#  'A young boy getting his picture taken on his birthday': 872,
#  'PERSON IN BLACK AND WHITE PICTURE HOLDING HAIR DRYER': 873,
#  'Shelves filled with cake and pastries in a store': 874,
#  'The view from the inside of a jetliner looking out over the earth': 875,
#  'An old World War II fighter plane flying overhead': 876,
#  'Many motorcycles are lined up next to each other with several people standing among them in front of a lot of trees': 877,
#  'An elephant reaching its trunk over the fence': 878,
#  'A group of young men playing a game of frisbee': 879,
#  'A brown cow is lying beside a motorcycle': 880,
#  'A man in a black wet suit on a surfboard': 881,
#  'Man paddling small boat on river in native land': 882,
#  'two large trucks are in a parking lot': 883,
#  'Two birds are flying side by side in a cloudy sky': 884,
#  'A pizza sitting on top of a metal pan on a stove': 885,
#  'A man is wearing a leopard print robe': 886,
#  'A woman with a spatula using a Cuisinart on the floor': 887,
#  'A pair of personalized stuffed plush teddy bears': 888,
#  'A couple of deer standing next to a zebra on a grass field': 889,
#  'A set of traffic lights showing green next to a sign that says no turn on red': 890,
#  'a couple of people that are playing a wii': 891,
#  'A vase has artificial red roses in it': 892,
#  'The old airplane is roped off with plastic cones': 893,
#  'A group of sheep next to each other in dirt ': 894,
#  'A man in the air on a skateboard doing a trick': 895,
#  'Two surfers sit on the beach on their boards and watch the ocean waves': 896,
#  'A house with a freshly mowed lawn is preceded by a small dock with a boat': 897,
#  'A parade of horses with their riders fancifully dressed': 898,
#  'A van is driving on to the back of a ferry': 899,
#  'A group of men standing on a baseball field': 900,
#  'A man on a skateboard jumps in the air': 901,
#  'A group of people riding boards under a bridge': 902,
#  'A tower that has a clock on it': 903,
#  'An open can of mustard sits next to a meat sandwich with pickles and olives': 904,
#  'A group of green apples sitting on top of a wooden table': 905,
#  'A couple bottles of wine are on a table with a glass': 906,
#  'The two men are waiting on their boards to surf the waves ': 907,
#  'A woman on her phone sitting on a raised planter on a sidewalk': 908,
#  'A  bird flying very close to an airplane': 909,
#  'Clean bathroom with an orange checked shower curtain which is closed': 910,
#  'a bunch of bananas sitting next to a bowl of apples': 911,
#  'a close up of a small child brushing her teeth': 912,
#  'a blue bike rack is by the grass': 913,
#  'On a wintery day a snowboarder taking a high jump': 914,
#  'A pink dessert tray with cake a cupcake and a tart on it': 915,
#  'A couple of horses standing in a river next to an island': 916,
#  'A woman is holding a bunch of cellphones ': 917,
#  'A redwhieandblue fire hydrant is on the street in front of houses': 918,
#  'Sheep and yaks are standing around a bail of hay': 919,
#  'A sheep standing in a shaded area in a clearing in the woods': 920,
#  'A picnic with alcohol a large cooler a blender and mixers': 921,
#  'A modern style automated type parking meter near the road': 922,
#  'A person on a surfboard is riding a wave': 923,
#  'a white bus some buildings and a black car': 924,
#  'A laptop computer on a desk with a coffee mug next to it ': 925,
#  'a public transit bus on an open field': 926,
#  'A bathroom that has a toilet cabinets and shower': 927,
#  'A view of the ornate detailing on the roof of an old church': 928,
#  'Two guys fly a colorful kite next to a large body of water': 929,
#  'an image of a group of birds near the bench': 930,
#  'A man on a grassy field throwing a frisbee': 931,
#  'A man riding a wave on a surfboard in the ocean': 932,
#  'this is a sign in grass near a fence': 933,
#  'a plate with a sandwich salad and dressing on it ': 934,
#  'Someone flying a kite in a residential field': 935,
#  'A couple is sitting on a bench while a train is passing by': 936,
#  'Fruit and other foods separated in tin cans': 937,
#  'A street sign next to a building on a street': 938,
#  'A man in black shirt riding on a skateboard': 939,
#  'A ski lift surrounded by people riding skis': 940,
#  'a brown wooden table with a green vase and purple flowers': 941,
#  'A man makes a phone call while examining a utility box full of wires': 942,
#  'A man doing a grind on a skateboard ': 943,
#  'This pizza with fresh cherry tomatoes and 2 kinds of cheese is ready for the oven': 944,
#  'A man and a woman posing for a picture': 945,
#  'A pile of smoking hot coals sitting next to pots and pans': 946,
#  'A vase of white and green flowers on table': 947,
#  'Pigeon sitting on a park bench in the park': 948,
#  'a fire hydrant on a city street with a sky background': 949,
#  'A BLACK AND WHITE DOG SITTING IN THE PASSENGER SEAT ': 950,
#  'A person in a green vest is holding a slow down sign': 951,
#  'a man standing in the kitchen with the cabinet open ': 952,
#  'Two giraffe laying on a lush green field': 953,
#  'A gray tiger cat sleeping on top of a red and white checkered blanket': 954,
#  'A dog sleeping on a chair in the living room': 955,
#  'A red stop sign sitting under a couple of street signs': 956,
#  'A giraffe looks at the camera as it walks through the brush': 957,
#  'A skier is standing beside a rack of skis and snowboards': 958,
#  'some food with some sliced vegetables and a fork': 959,
#  'A herd of sheep walking across a snow covered field': 960,
#  'There is a bun on a plate with lettuce': 961,
#  'A pizza buffet sitting inside of a building next to a kitchen': 962,
#  'A black dog laying on a pile of clothes': 963,
#  'A woman is tossing an omelet in a frying pan': 964,
#  'a bath room with a toilet and a sink': 965,
#  'Two bowls of oranges are sitting on a metal surface': 966,
#  'A black and white cat is looking at a banana': 967,
#  'Someone who is enjoying some rest on the edge of the pier': 968,
#  'Looking down at a cup of coffee and a piece of cake': 969,
#  'this is a giraffe and some zebras being watched': 970,
#  'A bear walks onto a road from the adjacent hill': 971,
#  'A surfer riding through a barrel on a wave ': 972,
#  'A man wearing a hat while standing next to a  purple teddy bear': 973,
#  'The tennis player has pulled back his racquet': 974,
#  'A group of zebras standing in some dry brush': 975,
#  'Several elephants grabbing grass with their trunks ': 976,
#  'a nice living room with a large tv': 977,
#  'Three men look at a lamp post on a street corner': 978,
#  'A small stuffed animal with a shadow laying in the street': 979,
#  'A lot of sheep in a very small fenced in stall with hay on the floor': 980,
#  'a tennis player swinging a racket to hit a ball': 981,
#  'A baseball player swinging a bat over a base': 982,
#  'A BED NEATLY MADE WITH A TABLE NEXT TO IT': 983,
#  'A city street filled with traffic and line with tall buildings': 984,
#  'A very old fashion bus is sitting in front of a gentleman ': 985,
#  'A giraffe in a grass enclosure surrounded  by stone walls': 986,
#  'A lady helps too young children to make sandwiches': 987,
#  'A young boy wearing a jacket rides a green skateboard down the street': 988,
#  'A bed has a large brown canopy over it': 989,
#  'Two signs show a street is blocked and detoured': 990,
#  'a number of zebras in a field near one another ': 991,
#  'A kitten is laying on a keyboard of an open laptop': 992,
#  'Paper plates filled with leftover food on a picnic table': 993,
#  'Man holding back dog while sheep are held in a holding area ': 994,
#  'A double image of a woman preparing to hit a tennis ball with her racquet ': 995,
#  'A girl sitting in a restaurant smiling in front of a bread entre': 996,
#  'The clock tower is on the first floor of the tall building ': 997,
#  'The birthday cookie has icing shaped like a dog': 998,
#  'a bus that is driving down the road': 999,
#  ...}

# %%
with open("trainval_ans2label.pkl", "wb") as f:
    pickle.dump(ans2label,f)

# %% [markdown]
# ## Training dataset

# %%
df = pd.DataFrame(columns = ["question-id", "image-id", "question", "answer", "labels", "image"])

img_prefix = "/COCO_train2014_"

for question, annotation in zip(questions_train["questions"], annotations_train["annotations"]):
    if question["image_id"] != annotation["image_id"]:
        raise ValueError("Q&A not alligned!")
        
#     print(question)
#     print(annotation)
    filename = train_imgs_path + img_prefix+str(question["image_id"]).zfill(12)+".jpg"
    
    img = Image.open(filename)
    img_buffer = BytesIO()
    img.save(img_buffer, format=img.format)
    byte_data = img_buffer.getvalue()
    base64_str = base64.b64encode(byte_data) # bytes
    base64_str = base64_str.decode("utf-8") # str
#     print(base64_str)
    
    for answer in annotation["answers"]:
#         print(answer)
        
        new_record = {"question-id": question["question_id"], 
                      "image-id":question["image_id"], "question":remove_special(question["question"]),
                      "answer":'1.0|!+'+remove_special(answer), 
                      "labels":"a", "image": base64_str}
        df = df.append(new_record, ignore_index=True)

# %%
df.to_csv("vqa_train.tsv", sep = "\t", header=False, index=False)

# %%
import numpy as np
np.where(pd.isna(df))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df.tail()
# Out:
#       question-id image-id                        question  \
# 20703      299334   416648  What can be seen in this image
# 20704      299334   416648  What can be seen in this image
# 20705      299334   416648  What can be seen in this image
# 20706      299334   416648  What can be seen in this image
# 20707      299334   416648  What can be seen in this image
#
#                                                   answer labels  \
# 20703  1.0|!+A man sitting at a table with boxes of d...      a
# 20704  1.0|!+A man in black sweater sitting at a tabl...      a
# 20705  1.0|!+A older man enjoying a variety of pastri...      a
# 20706  1.0|!+a man cupping his face in his hand holdi...      a
# 20707  1.0|!+a person sitting at a table with boxes o...      a
#
#                                                    image
# 20703  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20704  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20705  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20706  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 20707  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...

# %% [markdown]
# ## Validation dataset

# %%
df = pd.DataFrame(columns = ["question-id", "image-id", "question", "answer", "labels", "image"])

img_prefix = "/COCO_val2014_"

for question, annotation in zip(questions_val["questions"], annotations_val["annotations"]):
    if question["image_id"] != annotation["image_id"]:
        raise ValueError("Q&A not alligned!")
        
#     print(question)
#     print(annotation)
    filename = val_imgs_path + img_prefix+str(question["image_id"]).zfill(12)+".jpg"
    
    img = Image.open(filename)
    img_buffer = BytesIO()
    img.save(img_buffer, format=img.format)
    byte_data = img_buffer.getvalue()
    base64_str = base64.b64encode(byte_data) # bytes
    base64_str = base64_str.decode("utf-8") # str
#     print(base64_str)
    
    for answer in annotation["answers"]:
#         print(answer)
        
        new_record = {"question-id": question["question_id"], 
                      "image-id":question["image_id"], "question":remove_special(question["question"]),
                      "answer":'1.0|!+'+remove_special(answer), 
                      "labels":"a", "image": base64_str}
        df = df.append(new_record, ignore_index=True)

# %%
np.where(pd.isnull(df))
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
df.head()
# Out:
#   question-id image-id                 question  \
# 0      299336   432397  What this image depicts
# 1      299336   432397  What this image depicts
# 2      299336   432397  What this image depicts
# 3      299336   432397  What this image depicts
# 4      299336   432397  What this image depicts
#
#                                               answer labels  \
# 0  1.0|!+A black and white photograph of a plane ...      a
# 1  1.0|!+A crowd of people standing around an air...      a
# 2  1.0|!+An old photo of a crowd of people surrou...      a
# 3      1.0|!+A lot of women standing by an airplane       a
# 4  1.0|!+A group of people crowded around small a...      a
#
#                                                image
# 0  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4  /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...

# %%
df.to_csv("vqa_val.tsv", sep = "\t", header=False, index=False)
