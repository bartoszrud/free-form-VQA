# %%
import json
import os
import pandas as pd

# %%
with open("../../data/prediction_val_sub01/val_predict.json", "r") as f_q:
    answers_val = json.load(f_q)

# %%
val_dataset = pd.read_csv("./vqa_val_sub01.tsv", sep="\t", 
                          names = ["question_id", "image-id", "question", "answer", "labels", "image"])
val_dataset.drop(["labels", "image"], inplace = True, axis=1)
val_dataset["answer"] = val_dataset.apply(
    lambda x: x["answer"].split('|!+')[1] , axis=1)

# %%
val_dataset
# Out:
#        question_id  image-id  \
# 0         67255013     67255
# 1        134103008    134103
# 2        478240008    478240
# 3        174091008    174091
# 4        151084001    151084
# ...            ...       ...
# 22325    359039000    359039
# 22326    198733001    198733
# 22327    178982001    178982
# 22328     68838002     68838
# 22329    310663002    310663
#
#                                                 question  \
# 0                     How many cars are on the crosswalk
# 1                       Are these people wearing helmets
# 2                           Are the men riding a bicycle
# 3                             How many servings of pizza
# 4                                    Is the man barefoot
# ...                                                  ...
# 22325                       What gender are the children
# 22326                              Is the guy in mid air
# 22327                                  What city is this
# 22328  How many bolts are holding the sign onto the b...
# 22329              What numbers are visible on the train
#
#                                                  answer
# 0                         0 0 cars are on the crosswalk
# 1               No these people are not wearing helmets
# 2                   No the men are not riding a bicycle
# 3                                 8 8 servings of pizza
# 4                            No the man is not barefoot
# ...                                                 ...
# 22325                             Male are the children
# 22326                         Yes the guy is in mid air
# 22327                                  New york is this
# 22328  4 4 bolts are holding the sign onto the building
# 22329                     2002 are visible on the train
#
# [22330 rows x 4 columns]

# %%
answers_df = pd.DataFrame(answers_val)
joined = answers_df.join(val_dataset.set_index("question_id"), on = "question_id",lsuffix="-generated", rsuffix="-gt")
cols = ["question_id", "image-id", "question", "answer-gt","answer-generated"]
joined = joined[cols]

# %%
joined
# Out:
#        question_id  image-id  \
# 0         67255013     67255
# 1        134103008    134103
# 2        478240008    478240
# 3        174091008    174091
# 4        151084001    151084
# ...            ...       ...
# 22325    359039000    359039
# 22326    198733001    198733
# 22327    178982001    178982
# 22328     68838002     68838
# 22329    310663002    310663
#
#                                                 question  \
# 0                     How many cars are on the crosswalk
# 1                       Are these people wearing helmets
# 2                           Are the men riding a bicycle
# 3                             How many servings of pizza
# 4                                    Is the man barefoot
# ...                                                  ...
# 22325                       What gender are the children
# 22326                              Is the guy in mid air
# 22327                                  What city is this
# 22328  How many bolts are holding the sign onto the b...
# 22329              What numbers are visible on the train
#
#                                               answer-gt  \
# 0                         0 0 cars are on the crosswalk
# 1               No these people are not wearing helmets
# 2                   No the men are not riding a bicycle
# 3                                 8 8 servings of pizza
# 4                            No the man is not barefoot
# ...                                                 ...
# 22325                             Male are the children
# 22326                         Yes the guy is in mid air
# 22327                                  New york is this
# 22328  4 4 bolts are holding the sign onto the building
# 22329                     2002 are visible on the train
#
#                                         answer-generated
# 0        3 3 cars are on the train viewed in the picture
# 1                                     0 are they playing
# 2                              This the hand of is human
# 3                          2 2 servings are on the table
# 4                              This the hand of is human
# ...                                                  ...
# 22325                                    1st is the book
# 22326  Itch the elephant is scratching its head again...
# 22327  seagulls are flying over the ocean with mounta...
# 22328                          4 4 bolts are on the sign
# 22329                      0 are visible in this picture
#
# [275870 rows x 5 columns]

# %%
joined.to_csv("../../data/prediction_val_sub01/preditctions_gt_q.csv")
