# %%
import json
import os

# %%
with open("../../ofa_results/val_predict.json", "r") as f_q:
    answers_val = json.load(f_q)

# %%
for answer in answers_val:
    print(answer["answer"])
# Out:
# sink area of a kitchen with coral colored shelving
# cat laying on the edge of a mat on a chair
# person standing on the ledge of a train going through countryside
# dog takes a nap next to his owner
# white and orange trains on a railroad passing through a city
# giraffe looks over edge of railing to get close to camera
# man wearing denim shirt and tie with spots
# person in a hat looking in the fridge
# woman with a kite on the sidewalk following behind man on bicycle
# man in black wet suit surfing a wave in ocean
# train engine pulling box cars along tree lined rails
# cat laying on the edge of a mat on a chair
# white and orange trains on a railroad passing through a city
# large trains are pulled into the train station
# small child waiting to bat in a little league game
# tree is a green and white plane taking off
# cat laying on the edge of a mat on a chair
# cat laying on the edge of a mat on a chair
# man standing in water off shore flying a kite
# ...
